# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv('./shuffled_movies_metadata.csv')
# Out:
# C:\Users\m\AppData\Local\Temp\ipykernel_15852\1118977830.py:1: DtypeWarning: Columns (0,2,5,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv('./shuffled_movies_metadata.csv')

# %%
df1.head(2)
# Out:
#    adult belongs_to_collection    budget  \
# 0  False                   NaN         0
# 1  False                   NaN  60000000
#
#                                               genres  \
# 0  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 1  [{'id': 10402, 'name': 'Music'}, {'id': 99, 'n...
#
#                         homepage     id    imdb_id original_language  \
# 0                            NaN  13105  tt0085970                en
# 1  http://www.thisisit-movie.com  13576  tt1477715                en
#
#                  original_title  \
# 0                       Mr. Mom
# 1  Michael Jackson's This Is It
#
#                                             overview  ... release_date  \
# 0  Jack and Caroline are a couple making a decent...  ...   1983-07-22
# 1  A compilation of interviews, rehearsals and ba...  ...   2009-10-28
#
#       revenue runtime                                   spoken_languages  \
# 0  64783827.0    91.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 1         0.0   111.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                   tagline       title  video  \
# 0  Released  When mom goes to work, dad goes berserk!     Mr. Mom  False
# 1  Released         Like You've Never Seen Him Before  This Is It  False
#
#   vote_average vote_count
# 0          6.5       79.0
# 1          6.7      253.0
#
# [2 rows x 24 columns]

# %%
df1.id
# Out:
# 0         13105
# 1         13576
# 2         13360
# 3         76076
# 4         13373
#           ...
# 45461     55418
# 45462     11214
# 45463    120850
# 45464    171581
# 45465      9395
# Name: id, Length: 45466, dtype: object

# %%
ids = [id for id in df1.id if '-' in str(id)]

ids
# Out:
# ['2012-09-29', '2014-01-01', '1997-08-20']

# %%
for id in ids:
    df1 = df1[df1.id!=id]

# %%
df1['id'] = df1['id'].astype(int)

# %% [markdown]
# * Shuffling

# %%
df1 = df1.sample(frac=1).reset_index(drop=True)
df1
# Out:
#        adult                              belongs_to_collection     budget  \
# 0      False                                                NaN          0
# 1      False                                                NaN          0
# 2      False                                                NaN          0
# 3      False                                                NaN          0
# 4      False                                                NaN  100000000
# ...      ...                                                ...        ...
# 45458  False                                                NaN          0
# 45459  False                                                NaN    3500000
# 45460  False  {'id': 222639, 'name': 'Detective Dee Collecti...          0
# 45461  False                                                NaN   14000000
# 45462  False  {'id': 460334, 'name': 'Bulldog Drummond (Rich...          0
#
#                                                   genres homepage      id  \
# 0                          [{'id': 18, 'name': 'Drama'}]      NaN   58156
# 1      [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...      NaN  416688
# 2                         [{'id': 35, 'name': 'Comedy'}]      NaN   91052
# 3                       [{'id': 10402, 'name': 'Music'}]      NaN  156356
# 4      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...      NaN   10601
# ...                                                  ...      ...     ...
# 45458                [{'id': 99, 'name': 'Documentary'}]      NaN  185292
# 45459  [{'id': 53, 'name': 'Thriller'}, {'id': 80, 'n...      NaN   11909
# 45460  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...      NaN  217923
# 45461  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...      NaN   22004
# 45462  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...      NaN    5056
#
#          imdb_id original_language                 original_title  \
# 0      tt1483753                sv        Till det som är vackert
# 1      tt3953186                en                      The Tribe
# 2      tt1946269                fr     J'Aime Regarder les Filles
# 3      tt0022026                en                           Kiki
# 4      tt0316396                en                      Peter Pan
# ...          ...               ...                            ...
# 45458  tt0065541                en  Chesty: A Tribute to a Legend
# 45459  tt0099426                cn                           牒血街頭
# 45460  tt2992146                zh                       狄仁杰之神都龙王
# 45461  tt0105636                en                       Trespass
# 45462  tt0060288                en         Deadlier Than the Male
#
#                                                 overview  ... release_date  \
# 0      Katarina is 20 years old. With a troubled past...  ...   2009-10-22
# 1      A family of three young sisters live out their...  ...   2016-06-18
# 2      Primo is an ordinary middle-class youngster st...  ...   2011-07-20
# 3      A young Frenchwoman is determined to get into ...  ...   1931-03-14
# 4      In stifling Edwardian London, Wendy Darling me...  ...   2003-12-25
# ...                                                  ...  ...          ...
# 45458  A tribute documentary on the most decorated U....  ...   1976-04-04
# 45459  When three close friends escape from Hong Kong...  ...   1990-08-17
# 45460  A prequel to "Detective Dee and the Mystery of...  ...   2013-09-27
# 45461  Two Arkansas firemen, Vince and Don, get hold ...  ...   1992-12-25
# 45462  In this 1967 drama, resourceful British agent ...  ...   1967-02-12
#
#            revenue runtime                                   spoken_languages  \
# 0              0.0   100.0           [{'iso_639_1': 'sv', 'name': 'svenska'}]
# 1              0.0    97.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2              0.0    92.0          [{'iso_639_1': 'fr', 'name': 'Français'}]
# 3              0.0    87.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4      121975011.0   113.0           [{'iso_639_1': 'en', 'name': 'English'}]
# ...            ...     ...                                                ...
# 45458          0.0    47.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 45459          0.0   130.0  [{'iso_639_1': 'cn', 'name': '广州话 / 廣州話'}, {'i...
# 45460   72287783.0   133.0               [{'iso_639_1': 'zh', 'name': '普通话'}]
# 45461          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 45462          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 0      Released  Katarina's eyes and mind are opened when liste...
# 1      Released                                                NaN
# 2      Released                                                NaN
# 3      Released                                                NaN
# 4      Released                   All children grow up except one.
# ...         ...                                                ...
# 45458  Released                                                NaN
# 45459  Released                                                NaN
# 45460  Released                                                NaN
# 45461  Released  They all came to the wrong place at the wrong ...
# 45462  Released                          For Hire: Deadly Weapons!
#
#                                              title  video vote_average  \
# 0                                             Pure  False          6.5
# 1                                        The Tribe  False          5.3
# 2                          18 Years Old and Rising  False          5.1
# 3                                             Kiki  False          0.0
# 4                                        Peter Pan  False          6.9
# ...                                            ...    ...          ...
# 45458                Chesty: A Tribute to a Legend  False          7.0
# 45459                           Bullet in the Head  False          7.7
# 45460  Young Detective Dee: Rise of the Sea Dragon  False          5.9
# 45461                                     Trespass  False          6.2
# 45462                       Deadlier Than the Male  False          6.3
#
#       vote_count
# 0           16.0
# 1            3.0
# 2           18.0
# 3            0.0
# 4          671.0
# ...          ...
# 45458        1.0
# 45459       52.0
# 45460       70.0
# 45461       46.0
# 45462        8.0
#
# [45463 rows x 24 columns]

# %% [markdown]
# - This task is a content based recommendation system
# - We will recommend movies to new users according to movie description/overview

# %%
df1.overview
# Out:
# 0        Katarina is 20 years old. With a troubled past...
# 1        A family of three young sisters live out their...
# 2        Primo is an ordinary middle-class youngster st...
# 3        A young Frenchwoman is determined to get into ...
# 4        In stifling Edwardian London, Wendy Darling me...
#                                ...
# 45458    A tribute documentary on the most decorated U....
# 45459    When three close friends escape from Hong Kong...
# 45460    A prequel to "Detective Dee and the Mystery of...
# 45461    Two Arkansas firemen, Vince and Don, get hold ...
# 45462    In this 1967 drama, resourceful British agent ...
# Name: overview, Length: 45463, dtype: object

# %% [markdown]
# ------------------------------
# * Preprocessing
#
# 1- Remove NAN values

# %%
df1.overview = df1.overview.fillna('')

# %%
ovs = [overview for overview in df1.overview]
titles = [title for title in df1.title]

print(titles[0])
print(ovs[0])
# Out:
# Pure
# Katarina is 20 years old. With a troubled past in a dreary suburb, her life seems to be already set in stone - until she discovers music. Everything changes when she hears a performance of Mozart’s 'Requiem' at the Gothenburg Concert Hall that sends her reeling and opens up a beautiful new world. She feels that she has to change her life and get as far away from her ugly reality as possible. But the path she has to follow proves to be a treacherous one, filled with lies, betrayal and a dangerous liaison with the married conductor Adam. Yet Katarina is ready to do anything to gain her new identity.

# %% [markdown]
# 2- Turn overviews into lowercase

# %%
ovs = [ov.lower() for ov in ovs]
titles = [str(title).lower() for title in titles]

# %%
print(titles[0])
print(ovs[0])
# Out:
# pure
# katarina is 20 years old. with a troubled past in a dreary suburb, her life seems to be already set in stone - until she discovers music. everything changes when she hears a performance of mozart’s 'requiem' at the gothenburg concert hall that sends her reeling and opens up a beautiful new world. she feels that she has to change her life and get as far away from her ugly reality as possible. but the path she has to follow proves to be a treacherous one, filled with lies, betrayal and a dangerous liaison with the married conductor adam. yet katarina is ready to do anything to gain her new identity.

# %% [markdown]
# 3- Remove Punctuations

# %%
import re

ovs = [re.sub(r'[^\w\s]', '', ov) for ov in ovs]

ovs[0]
# Out:
# 'katarina is 20 years old with a troubled past in a dreary suburb her life seems to be already set in stone  until she discovers music everything changes when she hears a performance of mozarts requiem at the gothenburg concert hall that sends her reeling and opens up a beautiful new world she feels that she has to change her life and get as far away from her ugly reality as possible but the path she has to follow proves to be a treacherous one filled with lies betrayal and a dangerous liaison with the married conductor adam yet katarina is ready to do anything to gain her new identity'

# %% [markdown]
# 4- Remove stopwords

# %%
from nltk.corpus import stopwords

english_stopwords = stopwords.words('english')

# %% [markdown]
# * split overviews into tokens and search for stopwords
# * lemmatizing every token

# %%
# import nltk
# nltk.download('omw-1.4')

# %%
from nltk.stem import WordNetLemmatizer
wnl = WordNetLemmatizer()

# %%
filtered_ovs = []
for ov in ovs:
    filtered_ov = []
    for t in ov.split():
        if t not in english_stopwords:
            filtered_ov.append(wnl.lemmatize(t, pos="v"))

    filtered_ovs.append(filtered_ov)
    
filtered_ovs
# Out:
# [['katarina',
#   '20',
#   'years',
#   'old',
#   'trouble',
#   'past',
#   'dreary',
#   'suburb',
#   'life',
#   'seem',
#   'already',
#   'set',
#   'stone',
#   'discover',
#   'music',
#   'everything',
#   'change',
#   'hear',
#   'performance',
#   'mozarts',
#   'requiem',
#   'gothenburg',
#   'concert',
#   'hall',
#   'send',
#   'reel',
#   'open',
#   'beautiful',
#   'new',
#   'world',
#   'feel',
#   'change',
#   'life',
#   'get',
#   'far',
#   'away',
#   'ugly',
#   'reality',
#   'possible',
#   'path',
#   'follow',
#   'prove',
#   'treacherous',
#   'one',
#   'fill',
#   'lie',
#   'betrayal',
#   'dangerous',
#   'liaison',
#   'marry',
#   'conductor',
#   'adam',
#   'yet',
#   'katarina',
#   'ready',
#   'anything',
#   'gain',
#   'new',
#   'identity'],
#  ['family',
#   'three',
#   'young',
#   'sisters',
#   'live',
#   'days',
#   'pandemic',
#   'consume',
#   'know',
#   'world',
#   'one',
#   'day',
#   'stranger',
#   'suddenly',
#   'show',
#   'world',
#   'change',
#   'ways',
#   'never',
#   'could',
#   'imagine'],
#  ['primo',
#   'ordinary',
#   'middleclass',
#   'youngster',
#   'study',
#   'baccalaureate',
#   'get',
#   'sidetrack',
#   'fall',
#   'love',
#   'rich',
#   'girl',
#   'soon',
#   'learn',
#   'deal',
#   'condescend',
#   'friends',
#   'look',
#   'upon',
#   'upstart'],
#  ['young',
#   'frenchwoman',
#   'determine',
#   'get',
#   'stay',
#   'show',
#   'business',
#   'matter',
#   'shes',
#   'determine',
#   'win',
#   'recently',
#   'divorce',
#   'man',
#   'heart',
#   'matter'],
#  ['stifle',
#   'edwardian',
#   'london',
#   'wendy',
#   'darling',
#   'mesmerize',
#   'brothers',
#   'every',
#   'night',
#   'bedtime',
#   'tales',
#   'swordplay',
#   'swashbuckling',
#   'fearsome',
#   'captain',
#   'hook',
#   'children',
#   'become',
#   'heroes',
#   'even',
#   'greater',
#   'story',
#   'peter',
#   'pan',
#   'fly',
#   'nursery',
#   'one',
#   'night',
#   'lead',
#   'moonlit',
#   'rooftops',
#   'galaxy',
#   'star',
#   'lush',
#   'jungles',
#   'neverland'],
#  ['five',
#   'brothers',
#   'similar',
#   'yet',
#   'different',
#   'raise',
#   'mother',
#   'widow',
#   'early',
#   'one',
#   'leave',
#   'family',
#   'return',
#   'pursue',
#   'gang',
#   'smugglers',
#   'find',
#   'shelter',
#   'family',
#   'revel',
#   'dark',
#   'secret',
#   'five',
#   'brothers',
#   'together',
#   'find',
#   'energy',
#   'defend',
#   'themself',
#   'mean',
#   'avenge',
#   'memory',
#   'murder',
#   'father'],
#  ['two',
#   'men',
#   'fortyish',
#   'wear',
#   'wive',
#   'abandon',
#   'everything',
#   'go',
#   'live',
#   'back',
#   'beyond',
#   'meet',
#   'truculent',
#   'priest',
#   'boozer',
#   'émile',
#   'recall',
#   'lifes',
#   'simple',
#   'pleasures',
#   'calm',
#   'want',
#   'soon',
#   'example',
#   'inspire',
#   'thousands',
#   'disorientate',
#   'males',
#   'flee',
#   'feminist',
#   '1970s',
#   'soon',
#   'arrive',
#   'squadron',
#   'nymphomaniac',
#   'amazons'],
#  ['classic',
#   '1969',
#   'documentary',
#   'man',
#   'black',
#   'capture',
#   'peak',
#   'first',
#   'many',
#   'loom',
#   'rollercoaster',
#   'career',
#   'fresh',
#   'heel',
#   'folsom',
#   'prison',
#   'album',
#   'cash',
#   'reveal',
#   'dark',
#   'intensity',
#   'raw',
#   'talent',
#   'make',
#   'country',
#   'music',
#   'star',
#   'cultural',
#   'icon',
#   'director',
#   'robert',
#   'elfstrom',
#   'get',
#   'closer',
#   'filmmaker',
#   'cash',
#   'see',
#   'perform',
#   'new',
#   'bride',
#   'june',
#   'carter',
#   'cash',
#   'rare',
#   'duet',
#   'bob',
#   'dylan',
#   'behind',
#   'scenes',
#   'friends',
#   'family',
#   'aspire',
#   'young',
#   'musicians'],
#  ['story',
#   'young',
#   'woman',
#   'rachael',
#   'meet',
#   'father',
#   'never',
#   'know',
#   'gene',
#   'mother',
#   'funeral',
#   'discover',
#   'father',
#   'completely',
#   'delusional',
#   'believe',
#   'dead',
#   'mother',
#   'rachael',
#   'visit',
#   'gene',
#   'assist',
#   'live',
#   'home',
#   'learn',
#   'suffer',
#   'disease',
#   'call',
#   'korsakovs',
#   'syndrome',
#   'form',
#   'retrograde',
#   'amnesia',
#   'mother',
#   'place',
#   'facility',
#   'treatment',
#   'year',
#   'earlier',
#   'remember',
#   'anything',
#   'past',
#   'age',
#   'thirtythree',
#   'believe',
#   'still',
#   'young',
#   'man',
#   'unable',
#   'convince',
#   'really',
#   'rachael',
#   'decide',
#   'go',
#   'along',
#   'father',
#   'delusions',
#   'pretend',
#   'mother',
#   'discover',
#   'guise',
#   'gene',
#   'normal',
#   'conversations',
#   'long',
#   'rachael',
#   'visit',
#   'gene',
#   'everyday',
#   'find',
#   'new',
#   'ways',
#   'bring',
#   'elements',
#   'past',
#   'present',
#   'relationship'],
#  ['group',
#   'people',
#   'stand',
#   'along',
#   'platform',
#   'railway',
#   'station',
#   'la',
#   'ciotat',
#   'wait',
#   'train',
#   'one',
#   'see',
#   'come',
#   'distance',
#   'eventually',
#   'stop',
#   'platform',
#   'doors',
#   'railwaycars',
#   'open',
#   'attendants',
#   'help',
#   'passengers',
#   'popular',
#   'legend',
#   'film',
#   'show',
#   'firstnight',
#   'audience',
#   'flee',
#   'café',
#   'terror',
#   'fear',
#   'run',
#   'approach',
#   'train',
#   'legend',
#   'since',
#   'identify',
#   'promotional',
#   'embellishment',
#   'though',
#   'evidence',
#   'suggest',
#   'people',
#   'astound',
#   'capabilities',
#   'lumières',
#   'cinématographe'],
#  ['colonel',
#   'chabert',
#   'severely',
#   'wound',
#   'frenchrussian',
#   'napoleonic',
#   'war',
#   'point',
#   'medical',
#   'examiner',
#   'sign',
#   'death',
#   'certificate',
#   'regain',
#   'health',
#   'memory',
#   'go',
#   'back',
#   'paris',
#   'widow',
#   'anne',
#   'marry',
#   'count',
#   'ferraud',
#   'finance',
#   'rise',
#   'power',
#   'use',
#   'chaberts',
#   'money',
#   'chabert',
#   'hire',
#   'lawyer',
#   'help',
#   'get',
#   'back',
#   'money',
#   'honor'],
#  ['ash',
#   'friends',
#   'time',
#   'accompany',
#   'newcomer',
#   'dawn',
#   'arrive',
#   'idyllic',
#   'village',
#   'way',
#   'next',
#   'pokemon',
#   'contest',
#   'chaos',
#   'soon',
#   'erupt',
#   'prophecy',
#   'two',
#   'pokemon',
#   'gods',
#   'dialga',
#   'palkia',
#   'arrival',
#   'mysterious',
#   'seemingly',
#   'deadly',
#   'pokemon',
#   'name',
#   'darkrai',
#   'power',
#   'distort',
#   'space',
#   'time'],
#  ['handsome',
#   'backward',
#   'gardener',
#   'tim',
#   'melville',
#   'new',
#   'woman',
#   'life',
#   'mary',
#   'widow',
#   'employer',
#   'woman',
#   'give',
#   'love',
#   'find',
#   'tim',
#   'first',
#   'friends',
#   'soon',
#   'become',
#   'lovers',
#   'mary',
#   'draw',
#   'tims',
#   'innocence',
#   'magnetism',
#   'begin',
#   'teach',
#   'life',
#   'love'],
#  ['collection',
#   'death',
#   'scenes',
#   'range',
#   'tvmaterial',
#   'homemade',
#   'super8',
#   'movies',
#   'common',
#   'factor',
#   'death',
#   'mean'],
#  ['last',
#   'girlfriend',
#   'sleep',
#   'last',
#   'roommate',
#   'reno',
#   'rizzolla',
#   'move',
#   'la',
#   'new',
#   'girlfriend',
#   'chaos',
#   'ensue',
#   'debt',
#   'house',
#   'force',
#   'get',
#   'roommates'],
#  ['fiancé',
#   'break',
#   'engagement',
#   'danielle',
#   'leave',
#   'london',
#   'return',
#   'mother',
#   'jenny',
#   'paris',
#   'business',
#   'partner',
#   'benoît',
#   'jenny',
#   'run',
#   'appear',
#   'respectable',
#   'nightclub',
#   'fact',
#   'place',
#   'wealthy',
#   'men',
#   'buy',
#   'favour',
#   'attractive',
#   'young',
#   'women',
#   'oblivious',
#   'mother',
#   'professional',
#   'personal',
#   'life',
#   'danielle',
#   'meet',
#   'handsome',
#   'young',
#   'man',
#   'name',
#   'lucien',
#   'fall',
#   'love',
#   'realise',
#   'jennys',
#   'lover'],
#  ['lowermiddleclass',
#   'adams',
#   'family',
#   'father',
#   'son',
#   'happy',
#   'work',
#   'drugstore',
#   'mother',
#   'daughter',
#   'alice',
#   'try',
#   'every',
#   'possible',
#   'socialclimbing',
#   'stratagem',
#   'despite',
#   'snub',
#   'embarrassment',
#   'alice',
#   'finally',
#   'meet',
#   'dream',
#   'man',
#   'arthur',
#   'mother',
#   'nag',
#   'father',
#   'risky',
#   'business',
#   'venture',
#   'plan',
#   'impress',
#   'alices',
#   'beau',
#   'upscale',
#   'family',
#   'dinner',
#   'excruciate',
#   'result',
#   'drive',
#   'arthur',
#   'away'],
#  ['documentary',
#   'present',
#   'rageh',
#   'omaar',
#   'reveal',
#   'live',
#   'hop',
#   'fear',
#   'young',
#   'generation',
#   'tehran',
#   'intrigue',
#   'talk',
#   'least',
#   'understand',
#   'city',
#   'world',
#   'today',
#   'omaar',
#   'director',
#   'paul',
#   'sapin',
#   'spend',
#   'year',
#   'arrange',
#   'permissions',
#   'contact',
#   'film',
#   'include',
#   'renowned',
#   'female',
#   'photojournalist',
#   'woman',
#   'ceo',
#   'international',
#   'transport',
#   'company',
#   'editor',
#   'youth',
#   'magazine',
#   'staff',
#   'drug',
#   'rehab',
#   'centre',
#   'pop',
#   'star'],
#  ['two',
#   'parallel',
#   'tales',
#   'redemption',
#   'century',
#   'apart',
#   'new',
#   'york',
#   'storyline',
#   'edge',
#   'hunt',
#   'angelas',
#   'gold',
#   'pay',
#   'back',
#   'debt',
#   'gradually',
#   'grow',
#   'closer',
#   'macedonian',
#   'story',
#   'brothers',
#   'end',
#   'fight',
#   'opposite',
#   'side',
#   'revolution',
#   'religious',
#   'elijah',
#   'take',
#   'side',
#   'ottoman',
#   'sultan',
#   'gunslinger',
#   'luke',
#   'join',
#   'teacher',
#   'macedonian',
#   'rebel'],
#  ['skate',
#   'star',
#   'sonja',
#   'henie',
#   'glenn',
#   'miller',
#   'orchestra',
#   'share',
#   'spotlight',
#   'sun',
#   'valley',
#   'serenade',
#   'henie',
#   'play',
#   'norwegian',
#   'refugee',
#   'adopt',
#   'band',
#   'pianist',
#   'john',
#   'payne',
#   'mistakenly',
#   'think',
#   'fullgrown',
#   'miss',
#   'henie',
#   '10yearold',
#   'little',
#   'girl',
#   'paynes',
#   'girlfriend',
#   'lynn',
#   'bari',
#   'soloist',
#   'miller',
#   'band',
#   'also',
#   'violently',
#   'jealous',
#   'sort',
#   'bari',
#   'quit',
#   'miller',
#   'pique',
#   'henie',
#   'stag',
#   'elaborate',
#   'ice',
#   'show',
#   'substitute',
#   'impromptu',
#   'spectacular',
#   'thrill',
#   'audience',
#   'sun',
#   'valley',
#   'resort',
#   'hotel',
#   'action',
#   'take',
#   'place',
#   'joan',
#   'davis',
#   'milton',
#   'berle',
#   'provide',
#   'comic',
#   'relief',
#   'music',
#   'romance',
#   'havent',
#   'live',
#   'youve',
#   'see',
#   'berle',
#   'ski',
#   'nicholas',
#   'brothers',
#   'dorothy',
#   'dandridge',
#   'perform',
#   'lively',
#   'chorus',
#   'chattanooga',
#   'choo',
#   'choo'],
#  ['fall',
#   'ill',
#   'yesterday',
#   'learn',
#   'hiv',
#   'positive',
#   'husband',
#   'denial',
#   'young',
#   'daughter',
#   'tend',
#   'yesterdays',
#   'one',
#   'goal',
#   'live',
#   'long',
#   'enough',
#   'see',
#   'child',
#   'go',
#   'school'],
#  ['dr',
#   'markway',
#   'research',
#   'prove',
#   'existence',
#   'ghost',
#   'investigate',
#   'hill',
#   'house',
#   'large',
#   'eerie',
#   'mansion',
#   'lurid',
#   'history',
#   'violent',
#   'death',
#   'insanity'],
#  ['theodore',
#   'young',
#   'spanish',
#   'engineer',
#   'work',
#   'professor',
#   'university',
#   'oklahoma',
#   'return',
#   'spain',
#   'enjoy',
#   'sabbatical',
#   'year',
#   'upon',
#   'arrival',
#   'discover',
#   'father',
#   'kill',
#   'mother',
#   'compensate',
#   'loss',
#   'buy',
#   'motorcycle',
#   'sidecar',
#   'travel',
#   'together',
#   'father',
#   'son',
#   'arrive',
#   'remote',
#   'mountain',
#   'village',
#   'seem',
#   'empty',
#   'happen',
#   'residents',
#   'church',
#   'every',
#   'day',
#   'mass',
#   'true',
#   'spectacle',
#   'jimmy',
#   'theodore',
#   'discover',
#   'peculiarities',
#   'people',
#   'attend',
#   'elections',
#   'hold',
#   'year',
#   'appoint',
#   'mayor',
#   'priest',
#   'teacher',
#   'bitch',
#   'addition',
#   'town',
#   'come',
#   'group',
#   'students',
#   'american',
#   'university',
#   'eaton',
#   'belgian',
#   'meteorologists',
#   'dissident',
#   'group',
#   'russian',
#   'army',
#   'choir',
#   'invade',
#   'people',
#   'hide'],
#  ['thrillerhorror',
#   'movie',
#   'tell',
#   'tale',
#   'young',
#   'girl',
#   'terrify',
#   'insane',
#   'mother',
#   'take',
#   'away',
#   'beloved',
#   'foster',
#   'mother',
#   'one',
#   'day',
#   'craze',
#   'real',
#   'mother',
#   'attempt',
#   'contact',
#   'girl',
#   'school',
#   'foster',
#   'mother',
#   'premonition',
#   'get',
#   'time',
#   'protect',
#   'girl',
#   'eventually',
#   'though',
#   'real',
#   'mother',
#   'boy',
#   'friend',
#   'carnival',
#   'clown',
#   'succeed',
#   'take',
#   'away',
#   'leave',
#   'bereave',
#   'foster',
#   'parent',
#   'enlist',
#   'assistance',
#   'parapsychologist',
#   'help',
#   'interpret',
#   'foster',
#   'mother',
#   'terrify',
#   'dream',
#   'psychic',
#   'connection',
#   'girl',
#   'find',
#   'late'],
#  ['threeway',
#   'love',
#   'affair',
#   'rome',
#   'early',
#   'seventies',
#   'construction',
#   'worker',
#   'oreste',
#   'young',
#   'fiancee',
#   'adelaide',
#   'meet',
#   'nello',
#   'cook',
#   'pizzeria',
#   'love',
#   'triangle',
#   'often',
#   'go',
#   'communist',
#   'rally',
#   'enjoy',
#   'filthy',
#   'beach',
#   'ostia',
#   'hostile',
#   'environment',
#   'leave',
#   'way',
#   'jealousy'],
#  ['superman',
#   'want',
#   'batman',
#   'join',
#   'new',
#   'superhero',
#   'team',
#   'batman',
#   'pride',
#   'selfsufficient',
#   'loner'],
#  ['joyride',
#   'headlights',
#   'turn',
#   'two',
#   'men',
#   'hit',
#   'kill',
#   'another',
#   'man',
#   'carry',
#   'satchel',
#   'full',
#   'money',
#   'two',
#   'men',
#   'decide',
#   'take',
#   'money',
#   'throw',
#   'body',
#   'pond',
#   'bury',
#   'money',
#   'coal',
#   'hill',
#   'next',
#   'morning',
#   'police',
#   'discover',
#   'body',
#   'kidnap',
#   '12year',
#   'blind',
#   'girl',
#   'melody',
#   'warehouse',
#   'near',
#   'site',
#   'hitandrun',
#   'determine',
#   'kidnapper',
#   'saw',
#   'girls',
#   'father',
#   'bring',
#   'ransom',
#   'also',
#   'witness',
#   'hitandrun',
#   'men',
#   'steal',
#   'ransom'],
#  ['cocky',
#   'researcher',
#   'sebastian',
#   'caine',
#   'work',
#   'project',
#   'make',
#   'live',
#   'creatures',
#   'invisible',
#   'hes',
#   'confident',
#   'hes',
#   'find',
#   'right',
#   'formula',
#   'test',
#   'soon',
#   'begin',
#   'vanish',
#   'problem',
#   'noone',
#   'determine',
#   'make',
#   'visible',
#   'caines',
#   'predicament',
#   'eventually',
#   'drive',
#   'mad',
#   'terrify',
#   'result'],
#  ['die',
#   'german',
#   'magnate',
#   'invite',
#   'youngest',
#   'son',
#   'daughterinlaw',
#   'home',
#   'discuss',
#   'future',
#   'familys',
#   'shipbuilding',
#   'empire',
#   'daughterinlaw',
#   'stumble',
#   'upon',
#   'secret',
#   'familys',
#   'nazi',
#   'past'],
#  ['deep',
#   'space',
#   'edge',
#   'galaxy',
#   'future',
#   'new',
#   'prisoner',
#   'arrive',
#   'top',
#   'security',
#   'prison',
#   'ship',
#   'psychiatric',
#   'research',
#   'unit',
#   'dante',
#   '01',
#   'sole',
#   'survivor',
#   'encounter',
#   'alien',
#   'force',
#   'beyond',
#   'imagine',
#   'saint',
#   'georges',
#   'man',
#   'possess',
#   'inner',
#   'demons',
#   'catch',
#   'battle',
#   'control',
#   'monstrous',
#   'power',
#   'within',
#   'power',
#   'infect',
#   'highly',
#   'dangerous',
#   'occupants',
#   'dante',
#   '01',
#   'gaolors',
#   'prisoners',
#   'alike',
#   'unleash',
#   'violent',
#   'rebellion',
#   'turn',
#   'terrify',
#   'labyrinthine',
#   'world',
#   'upside',
#   'otherworldly',
#   'hell',
#   'ship',
#   'depths',
#   'danger',
#   'redemption',
#   'must',
#   'journey',
#   'limit',
#   'must',
#   'confront',
#   'dragon'],
#  ['bank', 'robber', 'reflect', 'life', 'crime', 'hide', 'bank', 'heist'],
#  ['kaalo',
#   'hindi',
#   'horror',
#   'film',
#   'direct',
#   'wilson',
#   'louis',
#   'produce',
#   'yash',
#   'patnaik',
#   'mamta',
#   'patnaik',
#   'dhaval',
#   'gada',
#   'film',
#   'release',
#   '17',
#   'december',
#   '2010',
#   'beyond',
#   'dream',
#   'entertainment',
#   'ltd',
#   'banner',
#   'loosely',
#   'base',
#   '1990',
#   'american',
#   'science',
#   'fiction',
#   'horror',
#   'comedy',
#   'film',
#   'tremor'],
#  ['nazi',
#   'occupation',
#   'tunisia',
#   'strain',
#   'bond',
#   'friendship',
#   'muslim',
#   'woman',
#   'sephardic',
#   'jewess',
#   'prepare',
#   'marriages'],
#  ['nc17',
#   'whose',
#   'members',
#   'include',
#   'frank',
#   'rogala',
#   'vince',
#   'rogala',
#   'robin',
#   'canada',
#   'spend',
#   'two',
#   'decades',
#   'play',
#   'bar',
#   'los',
#   'angeles',
#   'orange',
#   'county',
#   '1980',
#   '1990',
#   'bill',
#   'exude',
#   'college',
#   'playlist',
#   'hit',
#   'boys',
#   'want',
#   'sex',
#   'get',
#   'two',
#   'videos',
#   'mtv',
#   '1990',
#   'change',
#   'name',
#   'nc17',
#   'revamp',
#   'style',
#   'grungier',
#   'floydinfluenced',
#   'sound',
#   'filmmaker',
#   'dov',
#   'kelemer',
#   'make',
#   'documentary',
#   'career',
#   'struggle',
#   'movie',
#   'completedit',
#   'play',
#   'cable',
#   'film',
#   'festivals',
#   'theaters',
#   'available',
#   'wwwanybodylistencom',
#   'site',
#   'nc17',
#   'since',
#   'become',
#   'inactive',
#   'members',
#   'scatter',
#   'several',
#   'different',
#   'state',
#   'lead',
#   'vocalist',
#   'frank',
#   'rogala',
#   'remain',
#   'active',
#   'oc',
#   'music',
#   'scene'],
#  ['spring',
#   '1938',
#   'mountains',
#   'north',
#   'chile',
#   'fiery',
#   'ufo',
#   'later',
#   'name',
#   'chilean',
#   'sphere',
#   'fell',
#   'investigation',
#   'episode',
#   'make',
#   'film',
#   'crew',
#   'lead',
#   'sensational',
#   'discovery',
#   'appear',
#   'second',
#   'world',
#   'war',
#   'thirties',
#   'ussr',
#   'secret',
#   'space',
#   'program',
#   'develop',
#   'soviet',
#   'scientists',
#   'military',
#   'authorities',
#   'manage',
#   'launch',
#   'first',
#   'spacecraft',
#   '23',
#   'years',
#   'prior',
#   'jury',
#   'gagarins',
#   'flight',
#   'first',
#   'moon',
#   'tell',
#   'everyday',
#   'life',
#   'heroic',
#   'deeds',
#   'tragedy',
#   'first',
#   'group',
#   'soviet',
#   'cosmonauts',
#   'first',
#   'russian',
#   'film',
#   'shoot',
#   'rare',
#   'genre',
#   'mockumentary',
#   'documentary',
#   'fiction'],
#  ['base',
#   'book',
#   'ufo',
#   'crash',
#   'roswell',
#   'kevin',
#   'randle',
#   'donald',
#   'schmitt',
#   'roswell',
#   'follow',
#   'attempt',
#   'major',
#   'jesse',
#   'marcel',
#   'discover',
#   'truth',
#   'strange',
#   'debris',
#   'find',
#   'local',
#   'ranchers',
#   'field',
#   'july',
#   '1947',
#   'tell',
#   'superiors',
#   'find',
#   'nothing',
#   'down',
#   'weather',
#   'balloon',
#   'marcel',
#   'maintain',
#   'military',
#   'duty',
#   'weight',
#   'truth',
#   'however',
#   'world',
#   'may',
#   'force',
#   'piece',
#   'together',
#   'really',
#   'occur'],
#  ['family',
#   'saga',
#   'stun',
#   'mountain',
#   'valley',
#   'ranch',
#   'set',
#   'near',
#   'aspen',
#   'complex',
#   'dangerous',
#   'family',
#   'dynamics',
#   'play',
#   'backdrop',
#   'first',
#   'big',
#   'snowstorm',
#   'winter',
#   'enormous',
#   'panther',
#   'seemingly',
#   'mythical',
#   'qualities',
#   'kill',
#   'cattle'],
#  ['manager',
#   'orphanage',
#   'india',
#   'send',
#   'copenhagen',
#   'denmark',
#   'discover',
#   'lifealtering',
#   'family',
#   'secret'],
#  ['north',
#   'korea',
#   'one',
#   'worlds',
#   'isolate',
#   'nations',
#   'sixty',
#   'years',
#   'north',
#   'koreans',
#   'govern',
#   'totalitarian',
#   'regime',
#   'control',
#   'information',
#   'enter',
#   'leave',
#   'country',
#   'cult',
#   'personality',
#   'surround',
#   'two',
#   'recent',
#   'leaders',
#   'first',
#   'kim',
#   'il',
#   'sing',
#   'son',
#   'kim',
#   'jong',
#   'il'],
#  ['two',
#   'couple',
#   'robert',
#   'reed',
#   'june',
#   'kenney',
#   'joan',
#   'lora',
#   'eugene',
#   'persson',
#   'boat',
#   'trip',
#   'come',
#   'across',
#   'uncharted',
#   'island',
#   'four',
#   'investigate',
#   'find',
#   'clutch',
#   'dr',
#   'albert',
#   'balleau',
#   'wilton',
#   'graff',
#   'whose',
#   'hobby',
#   'hunt',
#   'animals',
#   'humans',
#   'group',
#   'try',
#   'escape',
#   'thwart',
#   'dr',
#   'balleau',
#   'henchmen'],
#  ['giulias',
#   'poise',
#   'world',
#   'make',
#   'rigour',
#   'sacred',
#   'texts',
#   'fiercely',
#   'exclude',
#   'belong',
#   'liberos',
#   'world',
#   'world',
#   'others',
#   'make',
#   'mistake',
#   'fend',
#   'look',
#   'another',
#   'chance',
#   'love',
#   'unconditionally',
#   'giulia',
#   'meet',
#   'libero',
#   'realize',
#   'another',
#   'destiny',
#   'one',
#   'choose',
#   'build'],
#  ['cash',
#   'mccall',
#   '1960',
#   'movie',
#   'star',
#   'jam',
#   'garner',
#   'natalie',
#   'wood',
#   'base',
#   'upon',
#   'novel',
#   'name',
#   'cameron',
#   'hawley',
#   'man',
#   'buy',
#   'businesses',
#   'order',
#   'sell',
#   'profit',
#   'recognize',
#   'critics',
#   'decades',
#   'ahead',
#   'time',
#   'numerous',
#   'ways',
#   'especially',
#   'hardcore',
#   'depiction',
#   'business',
#   'deal',
#   'innovative',
#   'film',
#   'direct',
#   'joseph',
#   'pevney',
#   'screenplay',
#   'lenore',
#   'j',
#   'coffee',
#   'marion',
#   'hargrove'],
#  ['young',
#   'robin',
#   'hood',
#   'love',
#   'maid',
#   'marian',
#   'enter',
#   'archery',
#   'contest',
#   'father',
#   'kings',
#   'palace',
#   'way',
#   'home',
#   'father',
#   'murder',
#   'henchmen',
#   'prince',
#   'john',
#   'robin',
#   'take',
#   'life',
#   'outlaw',
#   'gather',
#   'together',
#   'band',
#   'merry',
#   'men',
#   'sherwood',
#   'forest',
#   'avenge',
#   'father',
#   'death',
#   'help',
#   'people',
#   'land',
#   'prince',
#   'john',
#   'tax'],
#  ['group',
#   'travelers',
#   'strand',
#   'small',
#   'country',
#   'inn',
#   'river',
#   'flood',
#   'heavy',
#   'rain',
#   'bad',
#   'weather',
#   'continue',
#   'tensions',
#   'rise',
#   'amongst',
#   'travelers',
#   'trap',
#   'inn',
#   'ihei',
#   'misawa',
#   'ronin',
#   'samurai',
#   'without',
#   'master',
#   'whose',
#   'skills',
#   'sword',
#   'make',
#   'valuable',
#   'employee',
#   'whose',
#   'brutal',
#   'honesty',
#   'lack',
#   'social',
#   'grace',
#   'prevent',
#   'stay',
#   'one',
#   'master',
#   'long',
#   'one',
#   'night',
#   'ihei',
#   'impulsively',
#   'offer',
#   'buy',
#   'food',
#   'drink',
#   'guests',
#   'hotel',
#   'doesnt',
#   'money',
#   'pay',
#   'raise',
#   'cash',
#   'concoct',
#   'scheme',
#   'take',
#   'anyone',
#   'brave',
#   'enough',
#   'fight',
#   'prize',
#   'iheis',
#   'fight',
#   'skills',
#   'impress',
#   'lord',
#   'shigeaki',
#   'offer',
#   'position',
#   'fence',
#   'master',
#   'court',
#   'ihei',
#   'gratefully',
#   'accept',
#   'shigeaki',
#   'challenge',
#   'fight',
#   'ihei',
#   'beat',
#   'lord',
#   'decisively',
#   'ihea',
#   'certain',
#   'hes',
#   'manage',
#   'throw',
#   'another',
#   'opportunity',
#   'away',
#   'band',
#   'mercenaries',
#   'attack',
#   'skills',
#   'swordsman',
#   'put',
#   'ultimate',
#   'test'],
#  ['modern',
#   'version',
#   'ibsens',
#   'stage',
#   'play',
#   'meet',
#   'tvcelebrity',
#   'tomas',
#   'stockman',
#   'return',
#   'native',
#   'village',
#   'produce',
#   'worlds',
#   'purest',
#   'bottle',
#   'water',
#   'plant',
#   'bring',
#   'new',
#   'life',
#   'hope',
#   'village',
#   'unexpected',
#   'trouble',
#   'occur'],
#  ['young',
#   'widow',
#   'age',
#   'widowerreturnee',
#   'priest',
#   'bankrupt',
#   'parish',
#   'struggle',
#   'come',
#   'term',
#   'postwar',
#   'environment',
#   'complete',
#   'prejudice',
#   'illusions',
#   'unpleasant',
#   'mentality',
#   'follow',
#   'romantic',
#   'comedy',
#   'set',
#   'rough',
#   'landscape',
#   'woman',
#   'fall',
#   'love',
#   'local',
#   'priest',
#   'blind',
#   'love',
#   'unable',
#   'choose',
#   'church',
#   'circumstances',
#   'force',
#   'make',
#   'choice'],
#  ['jelena',
#   'woman',
#   'character',
#   'rule',
#   'inn',
#   'isolate',
#   'place',
#   'countryside',
#   'live',
#   'two',
#   'sons',
#   'martin',
#   'jakov',
#   'martin',
#   'marry',
#   'kata',
#   '5',
#   'years',
#   'never',
#   'succeed',
#   'child',
#   'jakov',
#   'sleep',
#   'mother',
#   'posture',
#   'suggest',
#   'incest',
#   'love',
#   'kata',
#   'night',
#   'hear',
#   'cry',
#   'sexual',
#   'act',
#   'husband',
#   'inevitably',
#   'finish',
#   'violence',
#   'one',
#   'day',
#   'jakov',
#   'cant',
#   'stand',
#   'anymore',
#   'leave',
#   'kata',
#   'find',
#   'dead',
#   'next',
#   'morning',
#   'two',
#   'character',
#   'arrive',
#   'old',
#   'man',
#   'turn',
#   'father',
#   'martin',
#   'settle',
#   'declare',
#   'return',
#   'die',
#   'girl',
#   'martin',
#   'keep',
#   'new',
#   'wife'],
#  ['director',
#   'martin',
#   'scorsese',
#   'profile',
#   'former',
#   'beatle',
#   'george',
#   'harrison',
#   'reverent',
#   'portrait',
#   'mix',
#   'interview',
#   'archival',
#   'footage',
#   'feature',
#   'commentary',
#   'like',
#   'paul',
#   'mccartney',
#   'eric',
#   'clapton',
#   'ringo',
#   'starr',
#   'yoko',
#   'ono'],
#  ['bbc',
#   'adaptation',
#   'victorian',
#   'penny',
#   'dreadful',
#   'tale',
#   '18th',
#   'century',
#   'demon',
#   'barber',
#   'sweeney',
#   'todd',
#   'fleet',
#   'street',
#   'cut',
#   'throats',
#   'unsuspecting',
#   'clients',
#   'london',
#   'shop'],
#  ['lazy',
#   'uneducated',
#   'male',
#   'students',
#   'mostly',
#   'come',
#   'money',
#   'share',
#   'close',
#   'band',
#   'live',
#   'together',
#   'dormitory',
#   'private',
#   'highschool',
#   'daily',
#   'plan',
#   'latest',
#   'prank',
#   'teachers',
#   'class',
#   'financial',
#   'crisis',
#   'headmaster',
#   'agree',
#   'enroll',
#   'female',
#   'students',
#   'new',
#   'students',
#   'try',
#   'fit',
#   'struggle',
#   'party',
#   'start',
#   'try',
#   'prank',
#   'part',
#   'away',
#   'prank',
#   'war',
#   'continue',
#   'peteacher',
#   'decide',
#   'take',
#   'class',
#   'trip',
#   'become',
#   'scout'],
#  [],
#  ['whale',
#   'august',
#   '1987',
#   'film',
#   'base',
#   'play',
#   'david',
#   'berry',
#   'star',
#   'bette',
#   'davis',
#   'lillian',
#   'gish',
#   'elderly',
#   'sisters',
#   'also',
#   'cast',
#   'ann',
#   'sothern',
#   'one',
#   'friends',
#   'vincent',
#   'price',
#   'peripheral',
#   'member',
#   'former',
#   'russian',
#   'aristocracy',
#   'film',
#   'shoot',
#   'location',
#   'maines',
#   'cliff',
#   'island',
#   'house',
#   'still',
#   'stand',
#   'popular',
#   'subject',
#   'artists',
#   'island',
#   'film',
#   'direct',
#   'lindsay',
#   'anderson',
#   'final',
#   'feature',
#   'film',
#   'screenplay',
#   'adapt',
#   'david',
#   'berry',
#   'play'],
#  ['group',
#   'teenagers',
#   'test',
#   'legend',
#   'immortal',
#   'witch',
#   'get',
#   'bargain',
#   'almost',
#   'halloween',
#   'six',
#   'young',
#   'people',
#   'spook',
#   'undaunted',
#   'folklore',
#   'surround',
#   'old',
#   'haunt',
#   'house',
#   'make',
#   'way',
#   'abide',
#   'legendary',
#   'wicked',
#   'perhaps',
#   'hop',
#   'provoke',
#   'malevolent',
#   'witch',
#   'clearly',
#   'prepare',
#   'theyve',
#   'certainly',
#   'unleash'],
#  ['dale',
#   'attractive',
#   'hardasnails',
#   'gay',
#   'male',
#   'escort',
#   'greenwich',
#   'london',
#   'specialise',
#   'fulfil',
#   'sexual',
#   'fantasy',
#   'dress',
#   'schoolboy',
#   'bdsm',
#   'name',
#   'hes',
#   'do',
#   'yet',
#   'dream',
#   'happy',
#   'end',
#   'complicate',
#   'straight',
#   'best',
#   'friend',
#   'childhood',
#   'crush',
#   'raj',
#   'announce',
#   'forthcoming',
#   'marriage',
#   'meanwhile',
#   'spate',
#   'gay',
#   'hate',
#   'crimes',
#   'report',
#   'local',
#   'heath'],
#  ['beautiful',
#   'halfbreed',
#   'pearl',
#   'chavez',
#   'become',
#   'ward',
#   'dead',
#   'father',
#   'first',
#   'love',
#   'find',
#   'tear',
#   'sons',
#   'one',
#   'good',
#   'bad'],
#  ['base',
#   'novel',
#   'panther',
#   'basement',
#   'worldrenowned',
#   'author',
#   'amos',
#   'oz',
#   'movie',
#   'take',
#   'place',
#   'palestine',
#   '1947',
#   'months',
#   'israel',
#   'become',
#   'state',
#   'proffy',
#   'liebowitz',
#   'militant',
#   'yet',
#   'sensitive',
#   'eleven',
#   'year',
#   'old',
#   'want',
#   'nothing',
#   'occupy',
#   'british',
#   'get',
#   'hell',
#   'land'],
#  ['spate',
#   'eerie',
#   'murder',
#   'erupt',
#   'across',
#   'hk',
#   'two',
#   'troubemaking',
#   'cop',
#   'assign',
#   'case',
#   'young',
#   'maverick',
#   'wang',
#   'grizzle',
#   'vet',
#   'huang',
#   'feed',
#   'reckless',
#   'younger',
#   'partner',
#   'always',
#   'land',
#   'hot',
#   'water',
#   'reach',
#   'dead',
#   'end',
#   'discover',
#   'victims',
#   'former',
#   'boyfriends',
#   'aspire',
#   'starlet',
#   'liu',
#   'detectives',
#   'must',
#   'play',
#   'deadly',
#   'game',
#   'one',
#   'must',
#   'go',
#   'undercover',
#   'lius',
#   'lover',
#   'lure',
#   'killer'],
#  ['five',
#   'friends',
#   'visit',
#   'grandfathers',
#   'house',
#   'country',
#   'hunt',
#   'terrorize',
#   'chainsaw',
#   'wield',
#   'killer',
#   'family',
#   'graverobbing',
#   'cannibals'],
#  ['four',
#   'best',
#   'friends',
#   'try',
#   'move',
#   'forward',
#   'work',
#   'personal',
#   'life',
#   'realize',
#   'try',
#   'live',
#   'lifes',
#   'dream',
#   'difficult',
#   'imagine',
#   'especially',
#   'high',
#   'fashion',
#   'world',
#   'shanghai'],
#  ['shuttlecock',
#   'boys',
#   'revolve',
#   'around',
#   'live',
#   'successes',
#   'failures',
#   'four',
#   'friends',
#   'hail',
#   'lowermiddleclass',
#   'background',
#   'delhi',
#   'accept',
#   'life',
#   'offer',
#   'us',
#   'platter',
#   'try',
#   'chase',
#   'dream',
#   'take',
#   'path',
#   'less',
#   'take',
#   'thats',
#   'question',
#   'protagonists',
#   'gaurav',
#   'manav',
#   'pankaj',
#   'loveleen',
#   'seek',
#   'answer',
#   'decide',
#   'embark',
#   'upon',
#   'eventful',
#   'journey',
#   'change',
#   'course',
#   'live',
#   'career',
#   'forever',
#   'one',
#   'thing',
#   'unite',
#   'four',
#   'friends',
#   'common',
#   'love',
#   'badminton',
#   'every',
#   'even',
#   'meet',
#   'couple',
#   'game',
#   'neighborhood',
#   'joke',
#   'live',
#   'pull',
#   'others',
#   'legs',
#   'part',
#   'day',
#   'pleasant',
#   'part',
#   'otherwise',
#   'dreary',
#   'live',
#   'play',
#   'badminton',
#   'one',
#   'night',
#   'decide',
#   'something',
#   'attempt',
#   'become',
#   'lifeline',
#   'put',
#   'litmus',
#   'test',
#   'determination',
#   'courage',
#   'luck',
#   'spirit',
#   'friendship'],
#  ['nineteenth',
#   'century',
#   'yorkshire',
#   'wealthy',
#   'orphan',
#   'anne',
#   'lister',
#   'live',
#   'aunt',
#   'uncle',
#   'anxious',
#   'marry',
#   'well',
#   'blissfully',
#   'unaware',
#   'lesbianrecording',
#   'thoughts',
#   'exploit',
#   'cod',
#   'diary',
#   'lover',
#   'mariana',
#   'belcombe',
#   'make',
#   'marriage',
#   'convenience',
#   'rich',
#   'old',
#   'charles',
#   'lawtonshe',
#   'feel',
#   'betray',
#   'andalthough',
#   'mariana',
#   'visit',
#   'sex',
#   'herthe',
#   'relationship',
#   'go',
#   'nowhere',
#   'help',
#   'old',
#   'flame',
#   'tib',
#   'make',
#   'play',
#   'innocent',
#   'miss',
#   'browne',
#   'see',
#   'bark',
#   'wrong',
#   'tree',
#   'divert',
#   'renovate',
#   'family',
#   'hall',
#   'drunken',
#   'tib',
#   'almost',
#   'expose',
#   'secret',
#   'scornful',
#   'mineowner',
#   'christopher',
#   'rawsonwhose',
#   'marriage',
#   'proposal',
#   'rejectstells',
#   'sexuality',
#   'subject',
#   'local',
#   'gossip',
#   'undeterred',
#   'anne',
#   'meet',
#   'ann',
#   'walker',
#   'become',
#   'new',
#   'wife',
#   'open',
#   'coalmine',
#   'live',
#   'happily',
#   'together',
#   'end',
#   'title',
#   'tell',
#   'us',
#   'anne',
#   'lister',
#   'die',
#   'prematurely',
#   '1840',
#   'holiday',
#   'russia'],
#  ['trouble',
#   'vietnam',
#   'war',
#   'vet',
#   'desert',
#   'wife',
#   'child',
#   'shortly',
#   'return',
#   'war',
#   'return',
#   '10',
#   'years',
#   'hes',
#   'live',
#   'like',
#   'animal',
#   'forest',
#   'find',
#   'unprepared',
#   'change',
#   'cope',
#   'vet',
#   'try',
#   'contact',
#   'son',
#   'realize',
#   'cause',
#   'damage',
#   'imagine'],
#  ['iron',
#   'monkey',
#   'hong',
#   'kong',
#   'variation',
#   'robin',
#   'hood',
#   'corrupt',
#   'officials',
#   'chinese',
#   'village',
#   'rob',
#   'mask',
#   'bandit',
#   'know',
#   'iron',
#   'monkey',
#   'name',
#   'benevolent',
#   'deity',
#   'else',
#   'fail',
#   'governor',
#   'force',
#   'travel',
#   'physician',
#   'find',
#   'bandit',
#   'arrival',
#   'evil',
#   'shaolin',
#   'monk',
#   'bring',
#   'physician',
#   'iron',
#   'monkey',
#   'together',
#   'battle',
#   'corrupt',
#   'government'],
#  ['moment',
#   'arrive',
#   'freiberg',
#   'germany',
#   'attend',
#   'prestigious',
#   'tan',
#   'academy',
#   'american',
#   'balletdancer',
#   'suzy',
#   'bannion',
#   'sense',
#   'something',
#   'horribly',
#   'evil',
#   'lurk',
#   'within',
#   'wall',
#   'ageold',
#   'institution'],
#  ['dolores',
#   'hart',
#   'leave',
#   'successful',
#   'hollywood',
#   'act',
#   'career',
#   'become',
#   'nun',
#   'true',
#   'story'],
#  ['inherit',
#   'money',
#   'harold',
#   'bissonette',
#   'pronounce',
#   'bisonay',
#   'decide',
#   'give',
#   'grocery',
#   'business',
#   'move',
#   'california',
#   'run',
#   'orange',
#   'grove',
#   'despite',
#   'familys',
#   'objections',
#   'news',
#   'land',
#   'buy',
#   'worthless',
#   'bissonette',
#   'pack',
#   'drive',
#   'california',
#   'nag',
#   'wife',
#   'amelia',
#   'children'],
#  ['two',
#   'thieve',
#   'blackbird',
#   'west',
#   'end',
#   'bertie',
#   'fall',
#   'love',
#   'girl',
#   'french',
#   'nightclub',
#   'performer',
#   'name',
#   'fifi',
#   'man',
#   'try',
#   'outdo',
#   'win',
#   'heart'],
#  ['renata',
#   'bella',
#   'feel',
#   'like',
#   'failure',
#   'life',
#   'career',
#   'renata',
#   'attend',
#   'seminar',
#   'sell',
#   'real',
#   'estate',
#   'finally',
#   'find',
#   'true',
#   'love',
#   'sam',
#   'sharpe',
#   'topnotch',
#   'successful',
#   'salesman',
#   'much',
#   'older',
#   'renata',
#   'sweep',
#   'away',
#   'excessively',
#   'flamboyant',
#   'style',
#   'irrepressible',
#   'nature',
#   'traits',
#   'find',
#   'romantic',
#   'however',
#   'lead',
#   'repeat',
#   'conflict',
#   'family',
#   'especially',
#   'beloved',
#   'father',
#   'joe',
#   'leave',
#   'renata',
#   'trap',
#   'middle'],
#  ['another',
#   'planet',
#   'distant',
#   'past',
#   'gelfling',
#   'embark',
#   'quest',
#   'find',
#   'miss',
#   'shard',
#   'magical',
#   'crystal',
#   'restore',
#   'order',
#   'world',
#   'grotesque',
#   'race',
#   'skeksis',
#   'find',
#   'use',
#   'crystal',
#   'evil'],
#  ['detectives',
#   'remote',
#   'town',
#   'pore',
#   'every',
#   'frame',
#   'trouble',
#   'tape',
#   'find',
#   'whereabouts',
#   'three',
#   'miss',
#   'college',
#   'students',
#   'chill',
#   'footage',
#   'become',
#   'disturb',
#   'students',
#   'come',
#   'upon',
#   'bloody',
#   'dress',
#   '8yearold',
#   'girl',
#   'seclude',
#   'wilderness',
#   'take',
#   'upon',
#   'find',
#   'link',
#   'case',
#   'miss',
#   'girl',
#   'miss',
#   'students',
#   'together',
#   'detectives',
#   'race',
#   'piece',
#   'enough',
#   'information',
#   'together',
#   'find',
#   'alive'],
#  ['director',
#   'robert',
#   'mulligans',
#   '1957',
#   'biographical',
#   'drama',
#   'star',
#   'anthony',
#   'perkins',
#   'jimmy',
#   'piersall',
#   'baseball',
#   'player',
#   'whose',
#   'career',
#   'interrupt',
#   'battle',
#   'mental',
#   'illness',
#   'cast',
#   'also',
#   'include',
#   'karl',
#   'malden',
#   'norma',
#   'moore',
#   'adam',
#   'williams',
#   'perry',
#   'wilson'],
#  ['tom',
#   'finland',
#   'one',
#   'gay',
#   'worlds',
#   'authentic',
#   'icons',
#   'draw',
#   'enormous',
#   'influence',
#   'gay',
#   'identity',
#   'toms',
#   'ultimate',
#   'leather',
#   'men',
#   'know',
#   'see',
#   'everywhere',
#   'symbols',
#   'gay',
#   'pride',
#   'friendship',
#   'documentary',
#   'include',
#   'titillate',
#   'enactments',
#   'inspire',
#   'toms',
#   'art',
#   'work'],
#  ['alan',
#   'ladd',
#   'canadian',
#   'focus',
#   'british',
#   'story',
#   'base',
#   'wartime',
#   'raid',
#   'german',
#   'radar',
#   'station',
#   'bruneval',
#   'raid',
#   'combine',
#   'service',
#   'operation',
#   '2nd',
#   'battalion',
#   '1st',
#   'parachute',
#   'brigade',
#   'lead',
#   'major',
#   'john',
#   'frost',
#   'major',
#   'snow',
#   'raf',
#   'radar',
#   'expert',
#   'flight',
#   'sergeant',
#   'cwh',
#   'cox',
#   'sergeant',
#   'box',
#   'accompany',
#   'raiders',
#   'tell',
#   'take',
#   'back',
#   'england',
#   'film',
#   'title',
#   'paratrooper',
#   'us'],
#  ['young',
#   'man',
#   'kentaro',
#   'saeki',
#   'haruma',
#   'miura',
#   'keep',
#   'fail',
#   'bar',
#   'test',
#   'know',
#   'older',
#   'sister',
#   'keiko',
#   'freelance',
#   'writer',
#   'kentaro',
#   'keiko',
#   'begin',
#   'search',
#   'information',
#   'grandfather',
#   'kyuzo',
#   'miyabe',
#   'junichi',
#   'okada',
#   'dead',
#   'special',
#   'force',
#   'world',
#   'war',
#   'ii',
#   'grandfather',
#   'kyuzo',
#   'miyabe',
#   'terrify',
#   'death',
#   'obsess',
#   'life',
#   'join',
#   'special',
#   'force',
#   'accord',
#   'fellow',
#   'navy',
#   'soldier',
#   'kyuzo',
#   'miyabe',
#   'genius',
#   'also',
#   'coward',
#   'kentaro',
#   'keiko',
#   'discover',
#   'shock',
#   'truth',
#   'seal',
#   '60',
#   'years'],
#  ['rock',
#   'musician',
#   'andy',
#   'mccoy',
#   'formerly',
#   'hanoi',
#   'rock',
#   'take',
#   'us',
#   'trip',
#   'mind',
#   'memories',
#   'imagination',
#   'documentaries',
#   'real',
#   'life',
#   'mr',
#   'mccoys',
#   'acid',
#   'mind',
#   'intertwine',
#   'form',
#   'interest',
#   'experience'],
#  ['ana',
#   'rios',
#   'former',
#   'miami',
#   'police',
#   'detectiveturnedlawyer',
#   'become',
#   'hellbent',
#   'seek',
#   'revenge',
#   'tragedy',
#   'shake',
#   'stable',
#   'existence',
#   'part',
#   'plan',
#   'plot',
#   'seek',
#   'gang',
#   'members',
#   'responsible',
#   'brothers',
#   'murder',
#   'ana',
#   'also',
#   'find',
#   'romance',
#   'former',
#   'boyfriend',
#   'hector',
#   'lead',
#   'complications'],
#  ['doctor',
#   'bernie',
#   'casey',
#   'watts',
#   'clinic',
#   'take',
#   'medicine',
#   'become',
#   'monstrous',
#   'white',
#   'killer',
#   'hookers'],
#  [],
#  ['ryan',
#   'jennifer',
#   'opposites',
#   'definitely',
#   'attract',
#   'least',
#   'thats',
#   'always',
#   'believe',
#   'meet',
#   'twelveyearolds',
#   'dislike',
#   'one',
#   'another',
#   'meet',
#   'teenagers',
#   'loathe',
#   'meet',
#   'college',
#   'uptight',
#   'ryan',
#   'freespirited',
#   'jennifer',
#   'find',
#   'differences',
#   'bind',
#   'together',
#   'rare',
#   'friendship',
#   'develop'],
#  ['romantic', 'comedy', 'invention', 'vibrator'],
#  ['impromptu',
#   'goodbye',
#   'party',
#   'professor',
#   'john',
#   'oldman',
#   'become',
#   'mysterious',
#   'interrogation',
#   'retire',
#   'scholar',
#   'reveal',
#   'colleagues',
#   'never',
#   'age',
#   'walk',
#   'earth',
#   '14000',
#   'years'],
#  ['struggle',
#   'young',
#   'fathertobe',
#   'give',
#   'temptation',
#   'impulsively',
#   'steal',
#   'envelope',
#   'money',
#   'office',
#   'corrupt',
#   'attorney',
#   'instead',
#   'hundred',
#   'dollars',
#   'contain',
#   '30000',
#   'decide',
#   'return',
#   'money',
#   'things',
#   'go',
#   'wrong',
#   'begin',
#   'trouble'],
#  ['weekend',
#   'boat',
#   'party',
#   'turn',
#   'nightmare',
#   'group',
#   'young',
#   'londoners',
#   'stumble',
#   'upon',
#   'terrify',
#   'secret',
#   'hide',
#   'reeds'],
#  ['unloved',
#   'film',
#   'give',
#   'childs',
#   'eye',
#   'view',
#   'uks',
#   'governmentrun',
#   'care',
#   'system',
#   'orphan',
#   'children',
#   'danger',
#   'lucy',
#   'eleven',
#   'years',
#   'old',
#   'neglect',
#   'estrange',
#   'mother',
#   'father',
#   'place',
#   'childrens',
#   'home',
#   'eye',
#   'follow',
#   'lucys',
#   'struggle',
#   'cope',
#   'system',
#   'save',
#   'selfbelief',
#   'certainty',
#   'watch',
#   'protect',
#   'holy',
#   'spirit',
#   'heroic',
#   'quest',
#   'love',
#   'beauty',
#   'transcendence'],
#  ['young',
#   'mother',
#   'daughter',
#   'escape',
#   'child',
#   'traffic',
#   'home',
#   'country',
#   'belarus',
#   'end',
#   'refugee',
#   'camp',
#   'northern',
#   'sweden',
#   'vulnerable',
#   'situation',
#   'become',
#   'easy',
#   'target',
#   'surround',
#   'soon',
#   'enough',
#   'get',
#   'put',
#   'front',
#   'extreme',
#   'choices',
#   'turn',
#   'life',
#   'nightmare'],
#  ['hector',
#   'star',
#   'basketball',
#   'player',
#   'college',
#   'basketball',
#   'team',
#   'play',
#   'leopards',
#   'girlfriend',
#   'olive',
#   'doesnt',
#   'know',
#   'whether',
#   'stay',
#   'leave',
#   'friend',
#   'gabriel',
#   'may',
#   'drop',
#   'school',
#   'become',
#   'protestor',
#   'want',
#   'desperately',
#   'get',
#   'draft',
#   'vietnam'],
#  ['movie',
#   'star',
#   'help',
#   'young',
#   'singeractress',
#   'find',
#   'fame',
#   'even',
#   'age',
#   'alcoholism',
#   'send',
#   'career',
#   'downward',
#   'spiral'],
#  ['manchurianruled',
#   'qing',
#   'dynasty',
#   'emperor',
#   'yong',
#   'zheng',
#   'establish',
#   'secret',
#   'assassination',
#   'squad',
#   'know',
#   'guillotine',
#   'eliminate',
#   'oppose',
#   'heavily',
#   'favor',
#   'emperor',
#   'guillotine',
#   'deem',
#   'expendable',
#   'emperor',
#   'qian',
#   'long',
#   'ascend',
#   'throne',
#   'adopt',
#   'western',
#   'ideas',
#   'technology',
#   'consolidate',
#   'power',
#   'new',
#   'regime',
#   'emperor',
#   'continue',
#   'use',
#   'guillotine',
#   'persecute',
#   'conquer',
#   'han',
#   'chinese',
#   'reign',
#   'terror',
#   'oppression',
#   'write',
#   'anynomous'],
#  [],
#  ['thomas',
#   'thomas',
#   'agoraphobic',
#   'computergenerated',
#   'girlfriend',
#   'hasnt',
#   'leave',
#   'home',
#   'years',
#   'prostitute',
#   'convince',
#   'leave',
#   'cyberspace',
#   'home',
#   'real',
#   'world'],
#  ['come', 'age', 'youth', 'name', 'sonny', 'small', 'texas', 'town', '1950s'],
#  ['francis',
#   'young',
#   'gay',
#   'man',
#   'marie',
#   'young',
#   'straight',
#   'woman',
#   'two',
#   'best',
#   'friends',
#   'day',
#   'gorgeous',
#   'nicolas',
#   'walk',
#   'montreal',
#   'coffee',
#   'shop',
#   'two',
#   'friends',
#   'instantly',
#   'equally',
#   'infatuate',
#   'compete',
#   'nicolas',
#   'indeterminate',
#   'affections',
#   'conflict',
#   'climax',
#   'trio',
#   'visit',
#   'vacation',
#   'home',
#   'nicolas',
#   'mother',
#   'frothy',
#   'comedy',
#   'unfold',
#   'narrative',
#   'fantasy',
#   'sequence',
#   'confessional',
#   'monologues'],
#  ['back',
#   'middle',
#   'school',
#   'summer',
#   'vacation',
#   'greg',
#   'heffley',
#   'older',
#   'brother',
#   'rodrick',
#   'must',
#   'deal',
#   'parent',
#   'misguide',
#   'attempt',
#   'bond'],
#  ['teen',
#   'girl',
#   'disappear',
#   'try',
#   'meet',
#   'men',
#   'online',
#   'order',
#   'escape',
#   'small',
#   'town',
#   'apparently',
#   'best',
#   'friend',
#   'worry',
#   'enough',
#   'investigate',
#   'mystery'],
#  ['1920s',
#   'ireland',
#   'elderly',
#   'couple',
#   'reside',
#   'tire',
#   'country',
#   'estate',
#   'live',
#   'highspirited',
#   'niece',
#   'oxford',
#   'student',
#   'nephew',
#   'marry',
#   'house',
#   'guests',
#   'try',
#   'cover',
#   'presently',
#   'homeless',
#   'niece',
#   'enjoy',
#   'romantic',
#   'frolic',
#   'soldier',
#   'hide',
#   'guerrilla',
#   'fighter',
#   'principals',
#   'throw',
#   'turmoil',
#   'one',
#   'guest',
#   'arrive',
#   'considerable',
#   'wit',
#   'unwanted',
#   'advice'],
#  ['young',
#   'boy',
#   'try',
#   'set',
#   'dad',
#   'date',
#   'death',
#   'mother',
#   'call',
#   'radio',
#   'station',
#   'talk',
#   'dads',
#   'loneliness',
#   'soon',
#   'lead',
#   'dad',
#   'meet',
#   'journalist',
#   'annie',
#   'fly',
#   'seattle',
#   'write',
#   'story',
#   'boy',
#   'dad',
#   'yet',
#   'annie',
#   'end',
#   'story',
#   'popular',
#   'romantic',
#   'comedy'],
#  ['adventurous',
#   'experiment',
#   'storytelling',
#   'secret',
#   'identities',
#   'miss',
#   'persons',
#   'lose',
#   'treasure',
#   'exotic',
#   'beasts',
#   'desperate',
#   'criminals',
#   'elements',
#   'weave',
#   'grand',
#   'tapestry',
#   'mysteries'],
#  ['five',
#   'years',
#   'yippie',
#   'founder',
#   'abbie',
#   'hoffman',
#   'go',
#   'underground',
#   'avoid',
#   'drugrelated',
#   'prison',
#   'sentence',
#   'contact',
#   'reporter',
#   'get',
#   'story',
#   'fbis',
#   'covert',
#   'spy',
#   'harassment',
#   'incite',
#   'violence',
#   'blame',
#   'leave'],
#  ['crime',
#   'wave',
#   'sweep',
#   'hong',
#   'kong',
#   'police',
#   'call',
#   'jessica',
#   'yang',
#   'yeoh',
#   'rise',
#   'star',
#   'rank',
#   'help',
#   'stop',
#   'notorious',
#   'gang',
#   'thieve',
#   'jessica',
#   'doesnt',
#   'realize',
#   'boyfriend',
#   'recently',
#   'discharge',
#   'force',
#   'leader',
#   'ruthless',
#   'crime',
#   'ring'],
#  ['kichijōji',
#   'station',
#   'tokyo',
#   'taku',
#   'morisaki',
#   'glimpse',
#   'familiar',
#   'woman',
#   'platform',
#   'opposite',
#   'board',
#   'train',
#   'later',
#   'photo',
#   'fall',
#   'shelf',
#   'exit',
#   'apartment',
#   'fly',
#   'kōchi',
#   'prefecture',
#   'pick',
#   'look',
#   'briefly',
#   'leave',
#   'aeroplane',
#   'take',
#   'narrate',
#   'events',
#   'bring',
#   'life'],
#  ['supernatural',
#   'thriller',
#   'lace',
#   'flashbacks',
#   'set',
#   'canadas',
#   'northwest',
#   'stranger',
#   'turn',
#   'mysterious',
#   'titular',
#   'figure',
#   'martin',
#   'come',
#   'small',
#   'quiet',
#   'town',
#   'seek',
#   'kill',
#   'wife',
#   'ana',
#   'suffer',
#   'dangerous',
#   'decease',
#   'make',
#   'addict',
#   'human',
#   'blood',
#   'like',
#   'however',
#   'arrive',
#   'town',
#   'discover',
#   'ana',
#   'dead',
#   'couple',
#   'years',
#   'decide',
#   'commit',
#   'suicide',
#   'definitely',
#   'eradicate',
#   'dangerous',
#   'decease',
#   'martins',
#   'brutally',
#   'attack',
#   'three',
#   'local',
#   'thugs',
#   'lead',
#   'caleb',
#   'son',
#   'corrupt',
#   'police',
#   'lieutenant',
#   'incident',
#   'suddenly',
#   'start',
#   'snowball',
#   'plunge',
#   'community',
#   'bloodbath'],
#  ['harsha',
#   'multimillionaire',
#   'guy',
#   'everything',
#   'something',
#   'else',
#   'hes',
#   'look',
#   'process',
#   'adopt',
#   'complete',
#   'village',
#   'try',
#   'bring',
#   'change',
#   'people'],
#  ['two',
#   'young',
#   'women',
#   'differ',
#   'view',
#   'love',
#   'find',
#   'three',
#   'suitors',
#   'sowmya',
#   'tabu',
#   'attract',
#   'attention',
#   'aspire',
#   'film',
#   'director',
#   'manohar',
#   'ajith',
#   'wound',
#   'captain',
#   'bala',
#   'mammootty',
#   'fall',
#   'younger',
#   'hopelessly',
#   'romantic',
#   'sister',
#   'meenu',
#   'aishwarya',
#   'rai',
#   'hesitate',
#   'much',
#   'older',
#   'meanwhile',
#   'meenu',
#   'meet',
#   'fall',
#   'businessman',
#   'passion',
#   'poetry',
#   'srikanth',
#   'abbas',
#   'manohar',
#   'go',
#   'madras',
#   'make',
#   'film',
#   'prove',
#   'worthy',
#   'sowmya',
#   'srikanths',
#   'business',
#   'collapse',
#   'also',
#   'depart',
#   'find',
#   'someone',
#   'lend',
#   'money',
#   'pay',
#   'investors'],
#  ['two',
#   'lovers',
#   'live',
#   'together',
#   'marry',
#   'hesitantly',
#   'explain',
#   'brother',
#   'make',
#   'promise',
#   'children',
#   'get',
#   'marry',
#   'grow',
#   'didnt',
#   'wait',
#   'important',
#   'plot',
#   'point',
#   'drive',
#   'cooper',
#   'action',
#   'discover',
#   'crawford',
#   'young',
#   'live',
#   'sin'],
#  ['young',
#   'man',
#   'release',
#   'reformatory',
#   'move',
#   'new',
#   'neighborhood',
#   'sister',
#   'intend',
#   'start',
#   'new',
#   'life',
#   'however',
#   'get',
#   'mix',
#   'local',
#   'mob',
#   'boss',
#   'corrupt',
#   'politicians',
#   'soon',
#   'find',
#   'frame',
#   'arson',
#   'murder',
#   'didnt',
#   'commit'],
#  ['sid',
#   'nancy',
#   'screenplay',
#   'author',
#   'abbe',
#   'wool',
#   'make',
#   'directorial',
#   'debut',
#   'tale',
#   'factory',
#   'worker',
#   'name',
#   'joe',
#   'x',
#   'front',
#   'man',
#   'john',
#   'doe',
#   'hit',
#   'road',
#   'harley',
#   'scatter',
#   'ash',
#   'coworker',
#   'join',
#   'wannabe',
#   'biker',
#   'sam',
#   'adam',
#   'horovitz',
#   'beastie',
#   'boys',
#   'joe',
#   'journey',
#   'los',
#   'angeles',
#   'nevada',
#   'meet',
#   'sort',
#   'character',
#   'play',
#   'like',
#   'david',
#   'carradine',
#   'john',
#   'cusack',
#   'timothy',
#   'leary',
#   'arlo',
#   'guthrie',
#   'along',
#   'way'],
#  ['gang',
#   'ruthless',
#   'highway',
#   'killers',
#   'kidnap',
#   'wealthy',
#   'couple',
#   'travel',
#   'cross',
#   'country',
#   'shockingly',
#   'discover',
#   'things',
#   'seem'],
#  ['mask',
#   'ball',
#   'paris',
#   'manuel',
#   'robledo',
#   'young',
#   'argentinian',
#   'architect',
#   'meet',
#   'elena',
#   'marquess',
#   'torre',
#   'blanca',
#   'later',
#   'young',
#   'woman',
#   'rightly',
#   'accuse',
#   'cause',
#   'misfortune',
#   'loss',
#   'wealth',
#   'fontenoy',
#   'man',
#   'fell',
#   'charm',
#   'escape',
#   'social',
#   'criticism',
#   'marquis',
#   'torre',
#   'blanca',
#   'transfer',
#   'residence',
#   'argentina',
#   'elena',
#   'meet',
#   'manuel',
#   'build',
#   'rivers',
#   'dam',
#   'manos',
#   'duras',
#   'thug',
#   'harass',
#   'elena',
#   'manuel',
#   'intervene',
#   'defy',
#   'whip',
#   'duel',
#   'duel',
#   'long',
#   'vicious',
#   'men',
#   'suffer',
#   'many',
#   'cut',
#   'face',
#   'naked',
#   'chests',
#   'end',
#   'thug',
#   'vanquish',
#   'humiliate',
#   'manos',
#   'duras',
#   'set',
#   'ambush',
#   'murder',
#   'manuel',
#   'marquis',
#   'torre',
#   'blanca',
#   'kill',
#   'instead',
#   'two',
#   'men',
#   'love',
#   'elena',
#   'eternal',
#   'temptress'],
#  ['sashas',
#   'mother',
#   'dream',
#   'sons',
#   'great',
#   'career',
#   'pianist',
#   'sasha',
#   'leave',
#   'speechless',
#   'reason',
#   'beloved',
#   'piano',
#   'teacher',
#   'mr',
#   'weber',
#   'tell',
#   'leave',
#   'town',
#   'forever',
#   'sasha',
#   'heartbroken',
#   'person',
#   'confide',
#   'feel',
#   'best',
#   'friend',
#   'jiao',
#   'son',
#   'exyugoslav',
#   'family',
#   'even',
#   'germany',
#   'one',
#   'rarely',
#   'live',
#   'outside',
#   'closet',
#   'sasha',
#   'grateful',
#   'homophobic',
#   'father',
#   'believe',
#   'jiao',
#   'girlfriend',
#   'begin',
#   'useful',
#   'lie',
#   'become',
#   'large',
#   'complicate',
#   'one',
#   'sashas',
#   'younger',
#   'brother',
#   'begin',
#   'affair',
#   'jiao',
#   'lie',
#   'get',
#   'expose',
#   'appear',
#   'catastrophe',
#   'fact',
#   'revelation',
#   'new',
#   'possibilities',
#   'live',
#   'sashas',
#   'family'],
#  ['stewart',
#   'mcbain',
#   'coleman',
#   'realestate',
#   'mogul',
#   'spend',
#   'live',
#   'blow',
#   'old',
#   'build',
#   'make',
#   'room',
#   'erect',
#   'new',
#   'build',
#   'go',
#   'plan',
#   'new',
#   'subdivision',
#   'group',
#   'protesters',
#   'object',
#   'destruction',
#   'one',
#   'lonely',
#   'ugly',
#   'build',
#   'call',
#   'dutch',
#   'house',
#   'typically',
#   'media',
#   'send',
#   'scene',
#   'protest',
#   'mcbain',
#   'appear',
#   'tv',
#   'bad',
#   'way',
#   'children',
#   'daphne',
#   'thurman',
#   'chloe',
#   'amis',
#   'jimmy',
#   'hewlett',
#   'ridicule',
#   'appear',
#   'tv',
#   'reward',
#   'remark',
#   'drop',
#   'dutch',
#   'house',
#   '750',
#   'apiece',
#   'tell',
#   'theyre',
#   'must',
#   'find',
#   'job',
#   'expect',
#   'make',
#   'money',
#   'stay',
#   'warm',
#   'mcbain',
#   'wife',
#   'jean',
#   'watch',
#   'afar',
#   'children',
#   'adapt',
#   'new',
#   'lifestyle',
#   'meet',
#   'new',
#   'friends',
#   'invite',
#   'others',
#   'new',
#   'home',
#   'include',
#   'decrepit',
#   'bum'],
#  ['card',
#   'sharp',
#   'unwillinglyenlisted',
#   'friends',
#   'need',
#   'make',
#   'lot',
#   'cash',
#   'quick',
#   'lose',
#   'sketchy',
#   'poker',
#   'match',
#   'decide',
#   'pull',
#   'heist',
#   'smalltime',
#   'gang',
#   'happen',
#   'operate',
#   'flat',
#   'next',
#   'door'],
#  [],
#  ['young',
#   'impulsive',
#   'rosetta',
#   'live',
#   'alcoholic',
#   'mother',
#   'move',
#   'despair',
#   'anything',
#   'maintain',
#   'job'],
#  ['supersucking',
#   'desert',
#   'creatures',
#   'back',
#   'time',
#   'theyre',
#   'south',
#   'border',
#   'creatures',
#   'worm',
#   'way',
#   'oil',
#   'field',
#   'mexico',
#   'people',
#   'wrangle',
#   'veteran',
#   'earl',
#   'bassett',
#   'survivalist',
#   'burt',
#   'gummer',
#   'add',
#   'team',
#   'young',
#   'punk',
#   'cash',
#   'fearless',
#   'scientist',
#   'critters',
#   'dont',
#   'stand',
#   'chance'],
#  ['penurious',
#   'musclebound',
#   'blake',
#   'thorne',
#   'make',
#   'vast',
#   'fortune',
#   'market',
#   'health',
#   'food',
#   'health',
#   'supplement',
#   'nice',
#   'fellow',
#   'wealth',
#   'increase',
#   'become',
#   'increasingly',
#   'selfcentered',
#   'decadent',
#   'one',
#   'day',
#   'get',
#   'great',
# ...
#   'hilarious',
#   'runaway',
#   'chain',
#   'even'],
#  ['base',
#   'book',
#   'megan',
#   'shull',
#   'swap',
#   'follow',
#   'adventure',
#   'rhythmic',
#   'gymnast',
#   'name',
#   'ellie',
#   'makeitorbreakit',
#   'competition',
#   'younger',
#   'brother',
#   'name',
#   'jack',
#   'hockey',
#   'family',
#   'whos',
#   'vie',
#   'varsity',
#   'spot',
#   'school',
#   'team',
#   'simple',
#   'text',
#   'cause',
#   'two',
#   'swap',
#   'body',
#   'paths',
#   'take',
#   'unexpected',
#   'cross'],
#  ['twin',
#   'feel',
#   'like',
#   'mom',
#   'tire',
#   'take',
#   'excite',
#   'adventure',
#   'grandmothers',
#   'house',
#   'encounter',
#   'pair',
#   'villains',
#   'along',
#   'way'],
#  ['look', 'inside', 'offbeat', 'board', 'school', 'young', 'girls'],
#  ['bosko',
#   'keep',
#   'wilbur',
#   'occupy',
#   'tales',
#   'past',
#   'exploit',
#   'honey',
#   'step',
#   'errand'],
#  ['ashfaque',
#   'ajay',
#   'devgan',
#   'small',
#   'town',
#   'boy',
#   'aspire',
#   'film',
#   'star',
#   'hindi',
#   'film',
#   'industry',
#   'join',
#   'street',
#   'theatre',
#   'group',
#   'run',
#   'reform',
#   'dacoit',
#   'sidhu',
#   'pankaj',
#   'kapur',
#   'use',
#   'street',
#   'theatre',
#   'medium',
#   'bring',
#   'awaken',
#   'mass',
#   'ashfaque',
#   'struggle',
#   'give',
#   'creative',
#   'vent',
#   'actor',
#   'order',
#   'realize',
#   'dream'],
#  ['right',
#   'wed',
#   'young',
#   'woman',
#   'find',
#   'abduct',
#   'hold',
#   'ransom',
#   'initial',
#   'days',
#   'pass',
#   'begin',
#   'develop',
#   'strange',
#   'bond',
#   'kidnapper'],
#  ['along',
#   'new',
#   'friends',
#   'teenager',
#   'arrest',
#   'us',
#   'secret',
#   'service',
#   'ban',
#   'use',
#   'computer',
#   'write',
#   'computer',
#   'virus',
#   'discover',
#   'plot',
#   'nefarious',
#   'hacker',
#   'must',
#   'use',
#   'computer',
#   'skills',
#   'find',
#   'evidence',
#   'pursue',
#   'secret',
#   'service',
#   'evil',
#   'computer',
#   'genius',
#   'behind',
#   'virus'],
#  ['rather',
#   'shady',
#   'private',
#   'detective',
#   'specialize',
#   'recover',
#   'highly',
#   'insure',
#   'items',
#   'get',
#   'involve',
#   'recover',
#   'steal',
#   'necklace',
#   'process',
#   'also',
#   'get',
#   'involve',
#   'secretary',
#   'insurance',
#   'company'],
#  ['chance',
#   'encounter',
#   'alter',
#   'teenage',
#   'girls',
#   'perception',
#   'outlook',
#   'life'],
#  ['luc',
#   'merenda',
#   'give',
#   'performance',
#   'career',
#   'highly',
#   'regard',
#   'police',
#   'detective',
#   'take',
#   'syndicate',
#   'money',
#   'exchange',
#   'departmental',
#   'favor',
#   'father',
#   'simple',
#   'man',
#   'also',
#   'work',
#   'department',
#   'lower',
#   'ring',
#   'isnt',
#   'jealous',
#   'son',
#   'rather',
#   'proud',
#   'little',
#   'know',
#   'hes',
#   'crook',
#   'cop',
#   'series',
#   'events',
#   'lead',
#   'young',
#   'detective',
#   'ask',
#   'father',
#   'favor',
#   'want',
#   'certain',
#   'police',
#   'report',
#   'desire',
#   'syndicate',
#   'doesnt',
#   'take',
#   'long',
#   'detectives',
#   'father',
#   'realize',
#   'son',
#   'take',
#   'lead',
#   'numerous',
#   'complications'],
#  ['uuno',
#   'go',
#   'wife',
#   'spend',
#   'summer',
#   'holiday',
#   'villa',
#   'country',
#   'study',
#   'play',
#   'violin',
#   'correspondence',
#   'course',
#   'construct',
#   'violin',
#   'doityourselfmethod',
#   'quit',
#   'career',
#   'perceive',
#   'take',
#   'free',
#   'time',
#   'much',
#   'come',
#   'back',
#   'live',
#   'life',
#   'shadow',
#   'fridge',
#   'start',
#   'scene',
#   'film',
#   'priest',
#   'ere',
#   'kokkonen',
#   'voice',
#   'say',
#   'uunos',
#   'weddings',
#   'complete',
#   'name',
#   'uuno',
#   'eero',
#   'turhapuro',
#   'whereas',
#   'later',
#   'uunofilms',
#   'uuno',
#   'daavid',
#   'goljat',
#   'turhapuro'],
#  ['nekhludoff',
#   'russian',
#   'nobleman',
#   'serve',
#   'jury',
#   'discover',
#   'young',
#   'girl',
#   'trial',
#   'katusha',
#   'someone',
#   'seduce',
#   'abandon',
#   'bear',
#   'responsibility',
#   'reduce',
#   'crime',
#   'set',
#   'redeem',
#   'process'],
#  ['giff',
#   'hoyt',
#   'cafe',
#   'owner',
#   'cabo',
#   'blanco',
#   'peru',
#   'world',
#   'war',
#   'ii',
#   'catch',
#   'refugeseeking',
#   'nazis',
#   'enemies',
#   'murder',
#   'sea',
#   'explorer',
#   'pass',
#   'accidental',
#   'death',
#   'corrupt',
#   'local',
#   'police',
#   'giff',
#   'become',
#   'suspicious',
#   'police',
#   'chief',
#   'also',
#   'intimidate',
#   'new',
#   'arrival',
#   'marie',
#   'giff',
#   'intervene',
#   'help',
#   'giff',
#   'suspect',
#   'beckdorff',
#   'nazi',
#   'refugee',
#   'live',
#   'area',
#   'beckdorff',
#   'emerge',
#   'seek',
#   'uncover',
#   'sink',
#   'treasure'],
#  ['brandon',
#   'play',
#   'brandon',
#   'regular',
#   'work',
#   'joe',
#   'hold',
#   'two',
#   'job',
#   'support',
#   'girlfriend',
#   'may',
#   'dream',
#   'own',
#   'motorcycle',
#   'brandons',
#   'best',
#   'friend',
#   'michael',
#   'ambitious',
#   'murderous',
#   'dope',
#   'peddler',
#   'michael',
#   'covet',
#   'may',
#   'come',
#   'plan',
#   'win',
#   'solve',
#   'problem',
#   'hes',
#   'seem',
#   'undercover',
#   'cop',
#   'name',
#   'sharky',
#   'use',
#   'police',
#   'connections',
#   'dominate',
#   'local',
#   'cocaine',
#   'trade',
#   'michael',
#   'kill',
#   'use',
#   'brandon',
#   'fall',
#   'guy',
#   'brandon',
#   'go',
#   'jail',
#   'though',
#   'think',
#   'release',
#   'soon',
#   'thank',
#   'efforts',
#   'good',
#   'buddy',
#   'michael',
#   'eight',
#   'years',
#   'later',
#   'brandon',
#   'finally',
#   'get',
#   'jail',
#   'vow',
#   'revenge'],
#  ['giovanna',
#   'darco',
#   'al',
#   'rogo',
#   'english',
#   'joan',
#   'arc',
#   'stake',
#   '1954',
#   'italian',
#   'film',
#   'direct',
#   'roberto',
#   'rossellini',
#   'star',
#   'wife',
#   'ingrid',
#   'bergman',
#   'show',
#   'live',
#   'performance',
#   'december',
#   '1953',
#   'san',
#   'carlo',
#   'theatre',
#   'naples',
#   'film',
#   'take',
#   'place',
#   'mostly',
#   'surrealistic',
#   'fantasy',
#   'around',
#   'time',
#   'execution',
#   'joan',
#   'arc',
#   'joan',
#   'arc',
#   'play',
#   'ingrid',
#   'bergman',
#   'burn',
#   'alive',
#   'heresy',
#   'kind',
#   'dream',
#   'state',
#   'depart',
#   'body',
#   'begin',
#   'look',
#   'back',
#   'upon',
#   'life',
#   'begin',
#   'journey',
#   'depress',
#   'demoralize',
#   'state',
#   'however',
#   'priest',
#   'appear',
#   'help',
#   'guide',
#   'first',
#   'show',
#   'accuse',
#   'guise',
#   'animal',
#   'character',
#   'order',
#   'show',
#   'true',
#   'nature',
#   'show',
#   'good',
#   'perform',
#   'people',
#   'end',
#   'proud',
#   'do',
#   'ready',
#   'face',
#   'flame'],
#  ['haewon',
#   'college',
#   'student',
#   'want',
#   'end',
#   'secret',
#   'affair',
#   'professor',
#   'seongjun',
#   'feel',
#   'depress',
#   'bid',
#   'farewell',
#   'mother',
#   'set',
#   'immigrate',
#   'canada',
#   'next',
#   'day',
#   'haewon',
#   'seek',
#   'seongjun',
#   'long',
#   'time',
#   'day',
#   'run',
#   'classmates',
#   'restaurant',
#   'relationship',
#   'get',
#   'reveal',
#   'haewon',
#   'get',
#   'agitate',
#   'seongjun',
#   'make',
#   'extreme',
#   'suggestion',
#   'run',
#   'away',
#   'together',
#   'haewon',
#   'dream',
#   'often',
#   'dream',
#   'compare',
#   'wake',
#   'life',
#   'none',
#   'deny',
#   'part',
#   'life'],
#  [],
#  ['whats',
#   'high',
#   'school',
#   'kid',
#   'get',
#   'popular',
#   'let',
#   'hair',
#   'howl',
#   'star',
#   'michael',
#   'j',
#   'fox',
#   'back',
#   'future',
#   'teen',
#   'wolf',
#   'outrageous',
#   'comedy',
#   'shy',
#   'teenager',
#   'change',
#   'voice',
#   'contend',
#   'hes',
#   'bud',
#   'young',
#   'werewolf',
#   'newfound',
#   'power',
#   'help',
#   'score',
#   'basketball',
#   'popular',
#   'girls',
#   'pretty',
#   'hairy',
#   'decisions',
#   'make'],
#  ['amangol',
#   'altinay',
#   'ghelich',
#   'taghani',
#   'eldest',
#   'daughter',
#   'poor',
#   'rural',
#   'family',
#   'help',
#   'support',
#   'head',
#   'shave',
#   'begin',
#   'work',
#   'boy',
#   'name',
#   'aman',
#   'isolate',
#   'carpet',
#   'weave',
#   'shop',
#   'girls',
#   'work',
#   'beat',
#   'owner',
#   'aman',
#   'toil',
#   'loom',
#   'hand',
#   'bleed',
#   'male',
#   'apprentice',
#   'supervise',
#   'girls',
#   'live',
#   'shop',
#   'lock',
#   'isolate'],
#  ['le',
#   'capitan',
#   '1960',
#   'frenchitalian',
#   'swashbuckler',
#   'film',
#   'direct',
#   'andré',
#   'hunebelle',
#   'star',
#   'jean',
#   'marais',
#   'bourvil',
#   'elsa',
#   'martinelli',
#   'lise',
#   'delamare',
#   'base',
#   'novel',
#   'michel',
#   'zévaco'],
#  ['jam',
#   'francos',
#   'sal',
#   'chronicle',
#   'final',
#   'hours',
#   'life',
#   'actor',
#   'sal',
#   'mineo',
#   'onetime',
#   'teen',
#   'idol',
#   'star',
#   'blockbuster',
#   'film',
#   'rebel',
#   'without',
#   'cause',
#   'exodus'],
#  ['havoc',
#   'create',
#   'small',
#   'southern',
#   'community',
#   '12yearold',
#   'show',
#   'cause',
#   'couple',
#   '13yearold',
#   'friends',
#   'fall',
#   'love',
#   'thus',
#   'possibly',
#   'jeopardize',
#   'friendship'],
#  ['lengthy',
#   'space',
#   'mission',
#   'two',
#   'astronauts',
#   'steve',
#   'barkett',
#   'larry',
#   'latham',
#   'return',
#   'earth',
#   'transform',
#   'nuclear',
#   'war',
#   'renegade',
#   'gang',
#   'mutants',
#   'rule',
#   'los',
#   'angeles',
#   'astronauts',
#   'join',
#   'two',
#   'pretty',
#   'women',
#   'couple',
#   'kid',
#   'grow',
#   'resistance',
#   'movement',
#   'scifi',
#   'adventure',
#   'follow',
#   'men',
#   'battle',
#   'bellbottomed',
#   'biker',
#   'leader',
#   'cutter',
#   'brutal',
#   'gang'],
#  ['fedoras',
#   'moms',
#   'underpants',
#   'puppy',
#   'love',
#   'make',
#   'jim',
#   'nortons',
#   'st',
#   'list',
#   'mouthful',
#   'shame'],
#  ['indian',
#   'biographical',
#   'sport',
#   'film',
#   'direct',
#   'tony',
#   'dsouza',
#   'base',
#   'life',
#   'former',
#   'indian',
#   'international',
#   'cricketer',
#   'mohammad',
#   'azharuddin',
#   'star',
#   'emraan',
#   'hashmi',
#   'lead',
#   'role',
#   'alongside',
#   'prachi',
#   'desai',
#   'nargis',
#   'fakhri',
#   'huma',
#   'qureshi'],
#  ['camp',
#   'belvidere',
#   'lesbian',
#   'romance',
#   'set',
#   '1950s',
#   'come',
#   'age',
#   'camp',
#   'leader',
#   'rise',
#   'forbid',
#   'encounter',
#   'nurse',
#   'gin',
#   'depict',
#   'journey',
#   'evolution',
#   'friendship',
#   'romance',
#   'two',
#   'women',
#   'rapport',
#   'would',
#   'unlikely'],
#  ['mothra',
#   'go',
#   'outer',
#   'space',
#   'stop',
#   'meteor',
#   'reach',
#   'earth',
#   'accidentally',
#   'take',
#   'cells',
#   'godzilla',
#   'remain',
#   'cells',
#   'biollante',
#   'inhabit',
#   'atmosphere',
#   'combine',
#   'cells',
#   'go',
#   'black',
#   'hole',
#   'create',
#   'new',
#   'creature',
#   'space',
#   'godzilla',
#   'space',
#   'godzilla',
#   'head',
#   'earth',
#   'confront',
#   'godzilla',
#   'junior',
#   'godzilla',
#   'new',
#   'gforce',
#   'robot',
#   'mogera'],
#  ['relationship',
#   'demand',
#   'piano',
#   'teacher',
#   'student',
#   'indian',
#   'prodigy'],
#  ['candyman',
#   'return',
#   'try',
#   'convince',
#   'female',
#   'descendent',
#   'artist',
#   'join',
#   'legendary',
#   'figure',
#   'end',
#   'frame',
#   'series',
#   'hideous',
#   'murder',
#   'friends',
#   'associate',
#   'nowhere',
#   'else',
#   'turn'],
#  ['1977',
#   'group',
#   'young',
#   'horny',
#   'control',
#   'christians',
#   'spend',
#   'fun',
#   'fill',
#   'weekend',
#   'mountain',
#   'lakeside',
#   'happy',
#   'day',
#   'bible',
#   'camp',
#   'one',
#   'one',
#   'youthful',
#   'sinners',
#   'pay',
#   'bloody',
#   'penance',
#   'misdeeds',
#   'flash',
#   'forward',
#   '7',
#   'years',
#   'another',
#   'youth',
#   'group',
#   'bible',
#   'toters',
#   'return',
#   'lead',
#   'father',
#   'richard',
#   'cummings',
#   'reggie',
#   'bannister',
#   'sister',
#   'mary',
#   'chopper',
#   'tim',
#   'sullivan',
#   'go',
#   'bloody',
#   'murder',
#   'camp',
#   'emphasis',
#   'camp',
#   'stand',
#   'performances',
#   'folks',
#   'like',
#   'gigi',
#   'bannister',
#   'jessica',
#   'sonneborn',
#   'troy',
#   'guthrie',
#   'deborah',
#   'venegas',
#   'jay',
#   'field',
#   'jeff',
#   'dylan',
#   'graham',
#   'end',
#   'bannister',
#   'troup',
#   'must',
#   'face',
#   'transvestite',
#   'serial',
#   'kill',
#   'nun',
#   'fight',
#   'death',
#   'call',
#   'upon',
#   'higher',
#   'grace',
#   'infamous',
#   'ron',
#   'jeremy',
#   'jesus',
#   'guide',
#   'hilarious',
#   'campy',
#   'equal',
#   'opportunity',
#   'offensive',
#   'film',
#   'die',
#   'laugh'],
#  ['group',
#   'stoners',
#   'inhale',
#   'bargain',
#   'smoke',
#   'evil',
#   'bong',
#   'campy',
#   'comedy',
#   'guy',
#   'buy',
#   'vintage',
#   'bong',
#   'name',
#   'eebee',
#   'ad',
#   'high',
#   'time',
#   'magazine',
#   'idea',
#   'possess',
#   'pipe',
#   'gradually',
#   'suck',
#   'horrify',
#   'surreal',
#   'world',
#   'fight',
#   'live',
#   'eebees',
#   'former',
#   'owner',
#   'none',
#   'tommy',
#   'chong',
#   'one',
#   'understand',
#   'power',
#   'bong',
#   'try',
#   'rescue'],
#  ['recent',
#   'loss',
#   'son',
#   'seana',
#   'minor',
#   'character',
#   'christmas',
#   'blessingpatty',
#   'addison',
#   'madeleine',
#   'stowe',
#   'devote',
#   'find',
#   'home',
#   'needy',
#   'children',
#   'loss',
#   'son',
#   'strain',
#   'pattys',
#   'relationship',
#   'husband',
#   'mark',
#   'reconnect',
#   'emotionally',
#   'take',
#   'emily',
#   '9yearold',
#   'orphan',
#   'car',
#   'accident',
#   'similar',
#   'one',
#   'kill',
#   'sean',
#   'time',
#   'dr',
#   'nathan',
#   'andrewsthe',
#   'one',
#   'character',
#   'connect',
#   'entire',
#   'film',
#   'trilogyis',
#   'try',
#   'find',
#   'parent',
#   'boy',
#   'die',
#   'er',
#   'mark',
#   'try',
#   'help',
#   'one',
#   'sons',
#   'friends',
#   'end',
#   'film',
#   'three',
#   'stories',
#   'intertwine',
#   'look',
#   'emily',
#   'run',
#   'away'],
#  ['eisenstein',
#   'get',
#   'trouble',
#   'shoot',
#   'grouse',
#   'tell',
#   'must',
#   'go',
#   'prison',
#   'crime',
#   'however',
#   'friend',
#   'invite',
#   'aristocratic',
#   'ball',
#   'eisenstein',
#   'despite',
#   'marry',
#   'want',
#   'go',
#   'ball',
#   'meet',
#   'women',
#   'eisenstein',
#   'lie',
#   'wife',
#   'tell',
#   'go',
#   'prison',
#   'actually',
#   'go',
#   'ball',
#   'story',
#   'arise',
#   'suspicion',
#   'wife',
#   'wife',
#   'devise',
#   'plot',
#   'catch',
#   'womanize',
#   'husband'],
#  ['hand',
#   'gods',
#   'true',
#   'story',
#   'five',
#   'young',
#   'british',
#   'freestyle',
#   'footballers',
#   'journey',
#   'across',
#   'americas',
#   'argentina',
#   'hope',
#   'meet',
#   'hero',
#   'diego',
#   'maradona',
#   'comingofage',
#   'road',
#   'movie',
#   'tell',
#   'story',
#   'group',
#   'young',
#   'men',
#   'pursuit',
#   'lifelong',
#   'dream'],
#  ['set',
#   'border',
#   'mexico',
#   'become',
#   'crucible',
#   'fearsome',
#   'gang',
#   'todays',
#   'mexican',
#   'countryside',
#   'gauntlet',
#   'freedom',
#   'stories',
#   'girl',
#   'live',
#   'honduras',
#   'hunger',
#   'brighter',
#   'future',
#   'two',
#   'teen',
#   'gang',
#   'members',
#   'mara',
#   'salvatrucha',
#   'near',
#   'entire',
#   'universe',
#   'become',
#   'interlace',
#   'train',
#   'border',
#   'journey',
#   'determine',
#   'future',
#   'live'],
#  ['live',
#   'let',
#   'live',
#   'feature',
#   'documentary',
#   'examine',
#   'relationship',
#   'animals',
#   'history',
#   'veganism',
#   'ethical',
#   'environmental',
#   'health',
#   'reason',
#   'move',
#   'people',
#   'go',
#   'vegan'],
#  ['rebel',
#   'leaders',
#   'map',
#   'strategy',
#   'allout',
#   'attack',
#   'emperors',
#   'newer',
#   'bigger',
#   'death',
#   'star',
#   'han',
#   'solo',
#   'remain',
#   'freeze',
#   'cavernous',
#   'desert',
#   'fortress',
#   'jabba',
#   'hutt',
#   'loathsome',
#   'outlaw',
#   'universe',
#   'also',
#   'keep',
#   'princess',
#   'leia',
#   'slave',
#   'girl',
#   'master',
#   'force',
#   'luke',
#   'skywalker',
#   'rescue',
#   'friends',
#   'cannot',
#   'become',
#   'true',
#   'jedi',
#   'knight',
#   'wag',
#   'crucial',
#   'battle',
#   'darth',
#   'vader',
#   'swear',
#   'win',
#   'luke',
#   'dark',
#   'side',
#   'force'],
#  ['german',
#   'soldier',
#   'john',
#   'gavin',
#   'home',
#   'leave',
#   'fall',
#   'love',
#   'girl',
#   'lilo',
#   'pulver',
#   'return',
#   'world',
#   'war',
#   'ii'],
#  ['dooley',
#   'k9',
#   'partner',
#   'jerry',
#   'lee',
#   'ready',
#   'retire',
#   'police',
#   'force',
#   'retire',
#   'pension',
#   'must',
#   'work',
#   'pi',
#   'find',
#   'set',
#   'high',
#   'tech',
#   'computer',
#   'chip'],
#  ['near',
#   'future',
#   'allergies',
#   'become',
#   'epidemic',
#   'music',
#   'producer',
#   'haru',
#   'halfheartedly',
#   'date',
#   'post',
#   'office',
#   'clerk',
#   'mail',
#   'thief',
#   'michi',
#   'search',
#   'violent',
#   'ways',
#   'reactivate',
#   'life',
#   'dream',
#   'escape',
#   'abroad',
#   'volunteer',
#   'test',
#   'new',
#   'drug',
#   'may',
#   'provide',
#   'cure'],
#  ['american',
#   'woman',
#   'strand',
#   'tokyo',
#   'break',
#   'boyfriend',
#   'search',
#   'direction',
#   'life',
#   'train',
#   'râmen',
#   'chef',
#   'tyrannical',
#   'japanese',
#   'master'],
#  ['story', 'friendship', 'lie', 'truth'],
#  ['offbeat',
#   'endear',
#   'romantic',
#   'comedy',
#   'unlikely',
#   'matchup',
#   'computer',
#   'date',
#   'straitlaced',
#   'dooley',
#   'thumb',
#   'overbear',
#   'father',
#   'singer',
#   'heflin',
#   'whose',
#   'life',
#   'wrap',
#   'familial',
#   'rock',
#   'group'],
#  ...]

# %%
print(ovs[0])
print([' '.join(ov) for ov in filtered_ovs][0])
# Out:
# katarina is 20 years old with a troubled past in a dreary suburb her life seems to be already set in stone  until she discovers music everything changes when she hears a performance of mozarts requiem at the gothenburg concert hall that sends her reeling and opens up a beautiful new world she feels that she has to change her life and get as far away from her ugly reality as possible but the path she has to follow proves to be a treacherous one filled with lies betrayal and a dangerous liaison with the married conductor adam yet katarina is ready to do anything to gain her new identity
# katarina 20 years old trouble past dreary suburb life seem already set stone discover music everything change hear performance mozarts requiem gothenburg concert hall send reel open beautiful new world feel change life get far away ugly reality possible path follow prove treacherous one fill lie betrayal dangerous liaison marry conductor adam yet katarina ready anything gain new identity

# %%
filtered_ovs = [' '.join(ov) for ov in filtered_ovs]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(stop_words='english')

# %%
tfidf_matrix = tfidf.fit_transform(filtered_ovs[:25000])

# %%
tfidf_matrix.shape
# Out:
# (25000, 58661)

# %%
len(filtered_ovs[:25000])
# Out:
# 25000

# %%
len(set(' '.join(filtered_ovs[:25000]).split()))
# Out:
# 58896

# %% [markdown]
# NOTE: approiximitly the same dimensions of tfidf_matrix

# %% [markdown]
# * Calculate cosine similarity between every overview and another

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
# del(cos_sim)
cos_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

# %%
cos_sim.shape
# Out:
# (25000, 25000)

# %%
indices = pd.Series(df1.index, index=df1['title']).drop_duplicates()

indices
# Out:
# title
# Pure                                               0
# The Tribe                                          1
# 18 Years Old and Rising                            2
# Kiki                                               3
# Peter Pan                                          4
#                                                ...
# Chesty: A Tribute to a Legend                  45458
# Bullet in the Head                             45459
# Young Detective Dee: Rise of the Sea Dragon    45460
# Trespass                                       45461
# Deadlier Than the Male                         45462
# Length: 45463, dtype: int64

# %% [markdown]
# NOTE: cos_sim matrix introduce similarity score between every movie and all movies in the dataset (20000 record)

# %%
def get_recommendation(title, n = 10):
    title = title.lower()

    ind = titles.index(title)

    if ind > 24999:
        return {'-': 'This movie doesn\'t exist in our dataset'}

    all_sim_movies_scores = cos_sim[ind].tolist()

    all_sim_movies_scores.pop(all_sim_movies_scores.index(max(all_sim_movies_scores)))

    top_movies = []
    scores = []
    i = 0
    while i < n:
        score = max(all_sim_movies_scores)
        most_sim_ind = all_sim_movies_scores.index(score)
        top_movies.append(titles[most_sim_ind])
        scores.append(f'{round(score*100, 2)}%')
        all_sim_movies_scores.pop(most_sim_ind)
        i = i+1

    return dict(zip(top_movies, scores))

# %%
rec_dict = get_recommendation('toy story')
pd.DataFrame(np.array([list(rec_dict.keys()), list(rec_dict.values())]).T, columns=['Movie', 'Similarity Score'])
# Out:
#   Movie                         Similarity Score
# 0     -  This movie doesn't exist in our dataset

# %%
rec_dict = get_recommendation('Assassins')
pd.DataFrame(np.array([list(rec_dict.keys()), list(rec_dict.values())]).T, columns=['Movie', 'Similarity Score'])
# Out:
#                                    Movie Similarity Score
# 0  the human centipede 2 (full sequence)            21.6%
# 1                                angel-a           15.55%
# 2                my mom is a character 2           14.57%
# 3               conan o'brien can't stop           14.42%
# 4                              hellsinki           14.02%
# 5              the flight of the phoenix           13.87%
# 6                     woman on the beach           13.68%
# 7                             dragon inn           13.43%
# 8                     the mummy's shroud           13.33%
# 9                       where's marlowe?           13.25%

# %%
import string

for x in get_recommendation('toy story'):
    print(df1[df1.original_title == string.capwords(x)]['genres'])
# Out:
# Series([], Name: genres, dtype: object)

# %%
# df1 = df1.sample(frac=1)
# df1.to_csv('shuffled_movies_metadata.csv', index=None)
